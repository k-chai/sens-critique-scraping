# %% [markdown]
# # Sens Critique
# ### Pourquoi un film fonctionne ?

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import re

link = 'https://www.senscritique.com'

# %% [markdown]
# ## Collecting data

# %% [markdown]
# Saving best films and their ratings in the Top

# %%
url_sc = link + '/films/tops/top111'
page_sc = requests.get(url_sc)
soup = BeautifulSoup(page_sc.content, "html.parser")

# collectiong data from page with top films

ranking_data = {}

films = soup.find_all('div', class_="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg")

for film in films:
    print(film)
    place = film.find('span', attrs={'data-testid': 'product-title-wrapper'}).find('span').text.strip()
    film_link = film.find('a', attrs={'data-testid': 'product-title'}).get('href')
    ratings = film.find('div', attrs={'data-testid': 'Rating'}).text
    ranking_data[place] = (film_link, ratings)
    
print(ranking_data)
# Out:
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/threat_level_midnight/449273" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000018640834/300/threat_level_midnight.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Threat Level Midnight" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Threat Level Midnight" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000018640834/300/threat_level_midnight.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.8</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>1. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/threat_level_midnight/449273">Threat Level Midnight (2011)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">30 min<!-- -->. </span><span data-testid="date-release">Sortie : 17 février 2011 (France). </span> <span data-testid="genres">Comédie</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Téléfilm </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Tucker_Gates/1110101"><span href="/contact/Tucker_Gates/1110101"><span>Tucker Gates</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span>Après 11 ans de préparation, Michael Scott nous livre enfin son épisode spécial Threat Level Midnight. Cet épisode met en scène Michael Scarn, son acolyte Dwight, et Jim : "Goldenface", ainsi ...
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/douze_hommes_en_colere/370894" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000017381024/300/douze_hommes_en_colere.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Douze Hommes en colère" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Douze Hommes en colère" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000017381024/300/douze_hommes_en_colere.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.7</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>2. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/douze_hommes_en_colere/370894">Douze Hommes en colère (1957)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">12 Angry Men</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">1 h 36 min<!-- -->. </span><span data-testid="date-release">Sortie : 4 octobre 1957 (France). </span> <span data-testid="genres">Policier, Drame</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Sidney_Lumet/7800"><span href="/contact/Sidney_Lumet/7800"><span>Sidney Lumet</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span>Douze jurés doivent décider du sort d'un jeune immigré, accusé de parric ...
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/harakiri/402373" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000015754717/300/harakiri.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Harakiri" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Harakiri" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000015754717/300/harakiri.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.6</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>3. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/harakiri/402373">Harakiri (1962)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Seppuku</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">2 h 13 min<!-- -->. </span><span data-testid="date-release">Sortie : 24 juillet 1963 (France). </span> <span data-testid="genres">Drame</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Masaki_Kobayashi/20521"><span href="/contact/Masaki_Kobayashi/20521"><span>Masaki Kobayashi</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span><span>Au XVIIe siècle, le Japon n’est plus en guerre et le pays est dirigé avec fermeté. Hanshirô Tsugumo, un rônin (samouraï errant) sans travail parmi tant d’autres, dé ...
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/blade_runner_the_final_cut/42244431" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000019400904/300/blade_runner_the_final_cut.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Blade Runner : The Final Cut" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Blade Runner : The Final Cut" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000019400904/300/blade_runner_the_final_cut.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.6</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>4. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/blade_runner_the_final_cut/42244431">Blade Runner : The Final Cut (2007)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">1 h 57 min<!-- -->. </span><span data-testid="date-release">Sortie : 5 octobre 2007. </span> <span data-testid="genres">Science-fiction</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Ridley_Scott/573"><span href="/contact/Ridley_Scott/573"><span>Ridley Scott</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span><span>Dans les dernières années du 20ème siècle, des milliers d'hommes et de femmes partent à la conquête de l'espace, fuyant les mégalopoles devenues insal ...
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/le_bon_la_brute_et_le_truand/368376" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000008032023/300/le_bon_la_brute_et_le_truand.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Le Bon, la Brute et le Truand" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Le Bon, la Brute et le Truand" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000008032023/300/le_bon_la_brute_et_le_truand.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.5</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>5. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/le_bon_la_brute_et_le_truand/368376">Le Bon, la Brute et le Truand (1966)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Il buono, il brutto, il cattivo</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">2 h 59 min<!-- -->. </span><span data-testid="date-release">Sortie : 8 mars 1968 (France). </span> <span data-testid="genres">Western, Aventure</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Sergio_Leone/3267"><span href="/contact/Sergio_Leone/3267"><span>Sergio Leone</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span>Un chasse ...
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/barberousse/368097" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000019677601/300/barberousse.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Barberousse" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Barberousse" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000019677601/300/barberousse.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.5</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>6. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/barberousse/368097">Barberousse (1965)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Akahige</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">3 h 05 min<!-- -->. </span><span data-testid="date-release">Sortie : 4 janvier 1978 (France). </span> <span data-testid="genres">Drame</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Akira_Kurosawa/1114"><span href="/contact/Akira_Kurosawa/1114"><span>Akira Kurosawa</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span>Nous sommes à Koishikawa au XIX° siècle. Kyojio Niide, un médecin hargneux mais généreux, décide d'entraîner un jeune apprenti, Noboru Yasumoto.</p></div></di ...
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/les_sept_samourais/451324" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000019238783/300/les_sept_samourais.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Les Sept Samouraïs" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Les Sept Samouraïs" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000019238783/300/les_sept_samourais.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.5</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>7. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/les_sept_samourais/451324">Les Sept Samouraïs (1954)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Shichinin no samurai</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">3 h 27 min<!-- -->. </span><span data-testid="date-release">Sortie : 30 novembre 1955 (France). </span> <span data-testid="genres">Arts martiaux, Aventure, Drame</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Akira_Kurosawa/1114"><span href="/contact/Akira_Kurosawa/1114"><span>Akira Kurosawa</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span>Dans un Japon médiéval meurtri par les guerres civiles, des bandits m ...
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/il_etait_une_fois_dans_l_ouest/440893" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000012461293/300/il_etait_une_fois_dans_l_ouest.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Il était une fois dans l'Ouest" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Il était une fois dans l'Ouest" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000012461293/300/il_etait_une_fois_dans_l_ouest.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.5</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>8. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/il_etait_une_fois_dans_l_ouest/440893">Il était une fois dans l'Ouest (1968)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">C'era una volta il West</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">2 h 55 min<!-- -->. </span><span data-testid="date-release">Sortie : 27 août 1969 (France). </span> <span data-testid="genres">Western</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Sergio_Leone/3267"><span href="/contact/Sergio_Leone/3267"><span>Sergio Leone</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span>L'histoire épiq ...
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/le_parrain/408443" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000020072264/300/le_parrain.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Le Parrain" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Le Parrain" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000020072264/300/le_parrain.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.5</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>9. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/le_parrain/408443">Le Parrain (1972)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">The Godfather</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">2 h 55 min<!-- -->. </span><span data-testid="date-release">Sortie : 18 octobre 1972 (France). </span> <span data-testid="genres">Policier, Drame</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Francis_Ford_Coppola/1387"><span href="/contact/Francis_Ford_Coppola/1387"><span>Francis Ford Coppola</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span><span>New York, 1945. Don Vito Corleone règne sur l'une des familles les plus puissantes de la mafia italo-américaine. Virgil Soll ...
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/il_etait_une_fois_en_amerique/804173" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000020028882/300/il_etait_une_fois_en_amerique.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Il était une fois en Amérique" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Il était une fois en Amérique" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000020028882/300/il_etait_une_fois_en_amerique.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.5</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>10. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/il_etait_une_fois_en_amerique/804173">Il était une fois en Amérique (1984)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Once Upon a Time in America</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">3 h 49 min<!-- -->. </span><span data-testid="date-release">Sortie : 23 mai 1984. </span> <span data-testid="genres">Drame, Gangster</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Sergio_Leone/3267"><span href="/contact/Sergio_Leone/3267"><span>Sergio Leone</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span><span>Il était une  ...
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/le_trou/440101" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000006297048/300/le_trou.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Le Trou" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Le Trou" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000006297048/300/le_trou.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.4</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>11. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/le_trou/440101">Le Trou (1960)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">2 h 12 min<!-- -->. </span><span data-testid="date-release">Sortie : 18 mars 1960. </span> <span data-testid="genres">Policier, Drame, Thriller</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Jacques_Becker/7028"><span href="/contact/Jacques_Becker/7028"><span>Jacques Becker</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span>Accusé de tentative de meurtre, Claude est enfermé en prison. Ses 4 compagnons de cellule lui font part de leur désir d'évasion et creusent un tunnel.</p></div></div>
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/point_limite/461381" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000014349574/300/point_limite.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Point limite" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Point limite" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000014349574/300/point_limite.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.4</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>12. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/point_limite/461381">Point limite (1964)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Fail-Safe</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">1 h 52 min<!-- -->. </span><span data-testid="date-release">Sortie : 25 février 1965 (France). </span> <span data-testid="genres">Drame, Thriller</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Sidney_Lumet/7800"><span href="/contact/Sidney_Lumet/7800"><span>Sidney Lumet</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span><span>En pleine guerre froide, dans un climat de tension grandissante, un escadron de bombardiers américains effectue une mission de reconnaiss ...
# ...
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/andrei_roublev/372818" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000016521009/300/andrei_roublev.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Andreï Roublev" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Andreï Roublev" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000016521009/300/andrei_roublev.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.2</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>48. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/andrei_roublev/372818">Andreï Roublev (1966)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Andrey Rublyov</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">3 h 03 min<!-- -->. </span><span data-testid="date-release">Sortie : décembre 1969 (France). </span> <span data-testid="genres">Drame, Biopic, Historique</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Andrei_Tarkovski/2243"><span href="/contact/Andrei_Tarkovski/2243"><span>Andreï Tarkovski</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span>En 1405, le peintre Théophane le Grec demande à Andreï Roublev de venir travailler avec lui à la décorat ...
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/fenetre_sur_cour/407292" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000013843742/300/fenetre_sur_cour.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="Fenêtre sur cour" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="Fenêtre sur cour" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000013843742/300/fenetre_sur_cour.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.1</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>49. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/fenetre_sur_cour/407292">Fenêtre sur cour (1954)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">Rear Window</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">1 h 52 min<!-- -->. </span><span data-testid="date-release">Sortie : 1 avril 1955 (France). </span> <span data-testid="genres">Thriller</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Alfred_Hitchcock/2622"><span href="/contact/Alfred_Hitchcock/2622"><span>Alfred Hitchcock</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span><span>À cause d'une jambe cassée, le reporter-photographe L. B. Jeffries est contraint de rester chez lui dans  ...
# <div class="ProductListItem__Wrapper-sc-1jkxxpj-1 kusRkg"><div class="ProductListItem__WrapperPoster-sc-1jkxxpj-2 gYYbKm"><div class="ProductActionsOnHover__Content-sc-1kgwlhz-0 fVFIuP" data-testid="product-actions-hover"><div class="Poster__Container-sc-yale2-1 jAoPdr" data-testid="poster" height="200" width="150"><a class="Poster__SubLink-sc-yale2-2 jhmgpI" data-testid="poster" height="200" href="/film/m_le_maudit/380190" width="150"><span class="Poster__WrapperImage-sc-yale2-9 ZhZbK" data-srcname="https://media.senscritique.com/media/000015265846/300/m_le_maudit.jpg" data-testid="poster-img-wrapper"><span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%"><span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%"><img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%27150%27%20height=%27200%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/></span><img alt="M le maudit" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/><noscript><img alt="M le maudit" data-cfstyle="22222" data-nimg="intrinsic" data-testid="poster-img" decoding="async" loading="lazy" src="https://media.senscritique.com/media/000015265846/300/m_le_maudit.jpg" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/></noscript></span></span></a><div class="Rating__GlobalRating-sc-1b09g9c-5 hdBBeX Poster__GlobalRating-sc-yale2-7 cpdRdc globalRating" data-testid="Rating">8.1</div></div></div></div><div class="ProductListItem__Content-sc-1jkxxpj-5 bmingM"><span class="Text__SCText-sc-1aoldkr-0 ProductTitle__PositionWrapper-sc-mtf7b1-0 kcGHBE bAswOf" data-testid="product-title-wrapper"><span>50. </span><h2 class="Text__SCText-sc-1aoldkr-0 kcGHBE"><a class="Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 kcGHBE jacWTu ProductListItem__StyledProductTitle-sc-1jkxxpj-3 dBFYVt" data-testid="product-title" href="/film/m_le_maudit/380190">M le maudit (1931)</a></h2></span><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__OriginalTitle-sc-1jkxxpj-4 gATBvH cWqDBb">M</p><p class="Text__SCText-sc-1aoldkr-0 ProductListItem__WrapperInfos-sc-1jkxxpj-10 eWSucP jEA-dBl" data-testid="other-infos"><span data-testid="duration">1 h 57 min<!-- -->. </span><span data-testid="date-release">Sortie : 8 avril 1932 (France). </span> <span data-testid="genres">Policier, Drame, Thriller</span></p><p class="Text__SCText-sc-1aoldkr-0 Creators__Text-sc-1ghc3q0-0 eWSucP LJhsB ProductListItem__StyledCreators-sc-1jkxxpj-6 ekAZTv" data-testid="creators"><span data-testid="creators-category"><span class="Creators__Universe-sc-1ghc3q0-1 ecDbNK"><span class="Text__SCText-sc-1aoldkr-0 eWSucP">Film </span></span><span class="Text__SCText-sc-1aoldkr-0 eWSucP">de </span></span><a class="Text__SCText-sc-1aoldkr-0 Link__PrimaryLink-sc-1v081j9-0 eWSucP bGxijB" data-testid="link" href="/contact/Fritz_Lang/1273"><span href="/contact/Fritz_Lang/1273"><span>Fritz Lang</span></span></a></p><p class="Text__SCText-sc-1aoldkr-0 ProductSynopsis__Text-sc-1lle9d2-0 gATBvI hpoRdH" data-testid="synopsis" type="default"><span class="ProductSynopsis__Bold-sc-1lle9d2-2 kWkZtq">Synopsis : </span>À Berlin, la police recherche un tueur d'enfants qui terrorise la ville. Alors qu'elle est impuissante, ce sont les criminels qui vont s'en charger.</p></div ...
# {'1.': ('/film/threat_level_midnight/449273', '8.8'), '2.': ('/film/douze_hommes_en_colere/370894', '8.7'), '3.': ('/film/harakiri/402373', '8.6'), '4.': ('/film/blade_runner_the_final_cut/42244431', '8.6'), '5.': ('/film/le_bon_la_brute_et_le_truand/368376', '8.5'), '6.': ('/film/barberousse/368097', '8.5'), '7.': ('/film/les_sept_samourais/451324', '8.5'), '8.': ('/film/il_etait_une_fois_dans_l_ouest/440893', '8.5'), '9.': ('/film/le_parrain/408443', '8.5'), '10.': ('/film/il_etait_une_fois_en_amerique/804173', '8.5'), '11.': ('/film/le_trou/440101', '8.4'), '12.': ('/film/point_limite/461381', '8.4'), '13.': ('/film/le_voyage_de_chihiro/1367079', '8.4'), '14.': ('/film/princesse_mononoke/376627', '8.4'), '15.': ('/film/entre_le_ciel_et_l_enfer/1324688', '8.4'), '16.': ('/film/l_aurore/451178', '8.3'), '17.': ('/film/vol_au_dessus_d_un_nid_de_coucou/447958', '8.3'), '18.': ('/film/dersou_ouzala/479434', '8.3'), '19.': ('/film/sherlock_junior/494192', '8.3'), '20.': ('/film/pour_sama/39231333', '8.3'), '21.': ('/film/parasite/25357970', '8.3'), '22.': ('/film/le_parrain_2e_partie/378648', '8.3'), '23.': ('/film/apocalypse_now/488421', '8.3'), '24.': ('/film/pulp_fiction/445539', '8.3'), '25.': ('/film/le_dictateur/478657', '8.3'), '26.': ('/film/voyage_au_bout_de_l_enfer/376439', '8.3'), '27.': ('/film/psychose/481802', '8.3'), '28.': ('/film/soy_cuba/390558', '8.2'), '29.': ('/film/la_femme_des_sables/409997', '8.2'), '30.': ('/film/les_affranchis/447001', '8.2'), '31.': ('/film/boulevard_du_crepuscule/465238', '8.2'), '32.': ('/film/requiem_pour_un_massacre/404608', '8.2'), '33.': ('/film/satantango_le_tango_de_satan/449796', '8.2'), '34.': ('/film/quand_passent_les_cigognes/438109', '8.2'), '35.': ('/film/le_tombeau_des_lucioles/486492', '8.2'), '36.': ('/film/la_condition_de_l_homme_1_il_n_y_a_pas_de_plus_grand_amour/480277', '8.2'), '37.': ('/film/les_enfants_du_paradis/384635', '8.2'), '38.': ('/film/midsommar_the_director_s_cut/39872454', '8.2'), '39.': ('/film/les_temps_modernes/459866', '8.2'), '40.': ('/film/la_vie_est_belle/434210', '8.2'), '41.': ('/film/les_lumieres_de_la_ville/449464', '8.2'), '42.': ('/film/rendez_vous/470029', '8.2'), '43.': ('/film/rebellion/442264', '8.2'), '44.': ('/film/le_chagrin_et_la_pitie/434213', '8.2'), '45.': ('/film/jeux_dangereux/465400', '8.2'), '46.': ('/film/eve/448394', '8.2'), '47.': ('/film/les_sentiers_de_la_gloire/415777', '8.2'), '48.': ('/film/andrei_roublev/372818', '8.2'), '49.': ('/film/fenetre_sur_cour/407292', '8.1'), '50.': ('/film/m_le_maudit/380190', '8.1')}

# %%
df_ranking = pd.DataFrame.from_dict(ranking_data, 
                                      orient='index', 
                                      columns=[
                                          'film_link',
                                          'ratings'
                                          ]
                                          )

df_ranking.tail()
# Out:
#                                   film_link ratings
# 46.                        /film/eve/448394     8.2
# 47.  /film/les_sentiers_de_la_gloire/415777     8.2
# 48.             /film/andrei_roublev/372818     8.2
# 49.           /film/fenetre_sur_cour/407292     8.1
# 50.                /film/m_le_maudit/380190     8.1

# %% [markdown]
# For films in the Top, scrape their:
# - title,
# - category,
# - how many people liked it _(likes)_

# %%
film_overall_data = {}

film_links_to_scrap = np.unique(df_ranking['film_link'])

for film in film_links_to_scrap:
    print(film)
    url_film = link + film
    page_film = requests.get(url_film)
    soup_film = BeautifulSoup(page_film.content, "html.parser")
    
    genres = []

    title = soup_film.find('h1', class_='Text__SCTitle-sc-1aoldkr-1 CoverProductInfos__Title-sc-1un0kh1-1 iTBZrv UiItd').text
    category = soup_film.find('span', attrs={'data-testid': 'creators-category'}).text
    likes = soup_film.find('p', class_='Text__SCText-sc-1aoldkr-0 Stats__Text-sc-1u6v943-2 gATBvI irORIr').text
    technical_info_link = soup_film.find('a', string='Fiche technique').get('href')
    
    film_overall_data[film] = (
        title,
        category,
        likes,
        technical_info_link
    )
    
print(film_overall_data)
# Out:
# /film/andrei_roublev/372818
# /film/apocalypse_now/488421
# /film/barberousse/368097
# /film/blade_runner_the_final_cut/42244431
# /film/boulevard_du_crepuscule/465238
# /film/dersou_ouzala/479434
# /film/douze_hommes_en_colere/370894
# /film/entre_le_ciel_et_l_enfer/1324688
# /film/eve/448394
# /film/fenetre_sur_cour/407292
# /film/harakiri/402373
# /film/il_etait_une_fois_dans_l_ouest/440893
# /film/il_etait_une_fois_en_amerique/804173
# /film/jeux_dangereux/465400
# /film/l_aurore/451178
# /film/la_condition_de_l_homme_1_il_n_y_a_pas_de_plus_grand_amour/480277
# /film/la_femme_des_sables/409997
# /film/la_vie_est_belle/434210
# /film/le_bon_la_brute_et_le_truand/368376
# /film/le_chagrin_et_la_pitie/434213
# /film/le_dictateur/478657
# /film/le_parrain/408443
# /film/le_parrain_2e_partie/378648
# /film/le_tombeau_des_lucioles/486492
# /film/le_trou/440101
# /film/le_voyage_de_chihiro/1367079
# /film/les_affranchis/447001
# /film/les_enfants_du_paradis/384635
# /film/les_lumieres_de_la_ville/449464
# /film/les_sentiers_de_la_gloire/415777
# /film/les_sept_samourais/451324
# /film/les_temps_modernes/459866
# /film/m_le_maudit/380190
# /film/midsommar_the_director_s_cut/39872454
# /film/parasite/25357970
# /film/point_limite/461381
# /film/pour_sama/39231333
# /film/princesse_mononoke/376627
# /film/psychose/481802
# /film/pulp_fiction/445539
# /film/quand_passent_les_cigognes/438109
# /film/rebellion/442264
# /film/rendez_vous/470029
# /film/requiem_pour_un_massacre/404608
# /film/satantango_le_tango_de_satan/449796
# /film/sherlock_junior/494192
# /film/soy_cuba/390558
# /film/threat_level_midnight/449273
# /film/vol_au_dessus_d_un_nid_de_coucou/447958
# /film/voyage_au_bout_de_l_enfer/376439
# {'/film/andrei_roublev/372818': ('Andreï Roublev', 'Film', '556', '/film/andrei_roublev/372818/details'), '/film/apocalypse_now/488421': ('Apocalypse Now', 'Film', '4.8K', '/film/apocalypse_now/488421/details'), '/film/barberousse/368097': ('Barberousse', 'Film', '836', '/film/barberousse/368097/details'), '/film/blade_runner_the_final_cut/42244431': ('Blade Runner : The Final Cut', 'Film', '118', '/film/blade_runner_the_final_cut/42244431/details'), '/film/boulevard_du_crepuscule/465238': ('Boulevard du crépuscule', 'Film', '1.2K', '/film/boulevard_du_crepuscule/465238/details'), '/film/dersou_ouzala/479434': ('Dersou Ouzala', 'Film', '868', '/film/dersou_ouzala/479434/details'), '/film/douze_hommes_en_colere/370894': ('Douze Hommes en colère', 'Film', '6.8K', '/film/douze_hommes_en_colere/370894/details'), '/film/entre_le_ciel_et_l_enfer/1324688': ("Entre le ciel et l'enfer", 'Film', '645', '/film/entre_le_ciel_et_l_enfer/1324688/details'), '/film/eve/448394': ('Ève...', 'Film', '693', '/film/eve/448394/details'), '/film/fenetre_sur_cour/407292': ('Fenêtre sur cour', 'Film', '2.7K', '/film/fenetre_sur_cour/407292/details'), '/film/harakiri/402373': ('Harakiri', 'Film', '1.5K', '/film/harakiri/402373/details'), '/film/il_etait_une_fois_dans_l_ouest/440893': ("Il était une fois dans l'Ouest", 'Film', '4K', '/film/il_etait_une_fois_dans_l_ouest/440893/details'), '/film/il_etait_une_fois_en_amerique/804173': ('Il était une fois en Amérique', 'Film', '3.4K', '/film/il_etait_une_fois_en_amerique/804173/details'), '/film/jeux_dangereux/465400': ('Jeux dangereux', 'Film', '1K', '/film/jeux_dangereux/465400/details'), '/film/l_aurore/451178': ("L'Aurore", 'Film', '1.2K', '/film/l_aurore/451178/details'), '/film/la_condition_de_l_homme_1_il_n_y_a_pas_de_plus_grand_amour/480277': ("La Condition de l'homme 1 - Il n'y a pas de plus grand amour", 'Film', '128', '/film/la_condition_de_l_homme_1_il_n_y_a_pas_de_plus_grand_amour/480277/details'), '/film/la_femme_des_sables/409997': ('La Femme des sables', 'Film', '395', '/film/la_femme_des_sables/409997/details'), '/film/la_vie_est_belle/434210': ('La Vie est belle', 'Film', '2K', '/film/la_vie_est_belle/434210/details'), '/film/le_bon_la_brute_et_le_truand/368376': ('Le Bon, la Brute et le Truand', 'Film', '5.5K', '/film/le_bon_la_brute_et_le_truand/368376/details'), '/film/le_chagrin_et_la_pitie/434213': ('Le Chagrin et la Pitié', 'Documentaire', '94', '/film/le_chagrin_et_la_pitie/434213/details'), '/film/le_dictateur/478657': ('Le Dictateur', 'Film', '2.4K', '/film/le_dictateur/478657/details'), '/film/le_parrain/408443': ('Le Parrain', 'Film', '5.6K', '/film/le_parrain/408443/details'), '/film/le_parrain_2e_partie/378648': ('Le Parrain - 2e Partie', 'Film', '2.8K', '/film/le_parrain_2e_partie/378648/details'), '/film/le_tombeau_des_lucioles/486492': ('Le Tombeau des lucioles', "Long-métrage d'animation", '6.6K', '/film/le_tombeau_des_lucioles/486492/details'), '/film/le_trou/440101': ('Le Trou', 'Film', '1.3K', '/film/le_trou/440101/details'), '/film/le_voyage_de_chihiro/1367079': ('Le Voyage de Chihiro', "Long-métrage d'animation", '10.6K', '/film/le_voyage_de_chihiro/1367079/details'), '/film/les_affranchis/447001': ('Les Affranchis', 'Film', '4.3K', '/film/les_affranchis/447001/details'), '/film/les_enfants_du_paradis/384635': ('Les Enfants du paradis', 'Film', '1K', '/film/les_enfants_du_paradis/384635/details'), '/film/les_lumieres_de_la_ville/449464': ('Les Lumières de la ville', 'Film', '943', '/film/les_lumieres_de_la_ville/449464/details'), '/film/les_sentiers_de_la_gloire/415777': ('Les Sentiers de la gloire', 'Film', '1.8K', '/film/les_sentiers_de_la_gloire/415777/details'), '/film/les_sept_samourais/451324': ('Les Sept Samouraïs', 'Film', '2.4K', '/film/les_sept_samourais/451324/details'), '/film/les_temps_modernes/459866': ('Les Temps modernes', 'Film', '2.2K', '/film/les_temps_modernes/459866/details'), '/film/m_le_maudit/380190': ('M le maudit', 'Film', '1.6K', '/film/m_l ...

# %%
df_films_overall = pd.DataFrame.from_dict(film_overall_data, 
                                  orient='index', 
                                      columns=[
                                          'title',
                                          'category', 
                                          'likes',
                                          'technical_info_link'
                                          ]
                                          )
df_films_overall.tail()
# Out:
#                                                                           title  \
# /film/sherlock_junior/494192                                    Sherlock Junior
# /film/soy_cuba/390558                                                  Soy Cuba
# /film/threat_level_midnight/449273                        Threat Level Midnight
# /film/vol_au_dessus_d_un_nid_de_coucou/447958  Vol au-dessus d'un nid de coucou
# /film/voyage_au_bout_de_l_enfer/376439                Voyage au bout de l'enfer
#
#                                                     category likes  \
# /film/sherlock_junior/494192                   Moyen-métrage   580
# /film/soy_cuba/390558                                   Film   488
# /film/threat_level_midnight/449273                  Téléfilm   123
# /film/vol_au_dessus_d_un_nid_de_coucou/447958           Film  6.6K
# /film/voyage_au_bout_de_l_enfer/376439                  Film  2.5K
#
#                                                                              technical_info_link
# /film/sherlock_junior/494192                                /film/sherlock_junior/494192/details
# /film/soy_cuba/390558                                              /film/soy_cuba/390558/details
# /film/threat_level_midnight/449273                    /film/threat_level_midnight/449273/details
# /film/vol_au_dessus_d_un_nid_de_coucou/447958  /film/vol_au_dessus_d_un_nid_de_coucou/447958/...
# /film/voyage_au_bout_de_l_enfer/376439            /film/voyage_au_bout_de_l_enfer/376439/details

# %% [markdown]
# For films in the Top, scrape additional information about their:
# - Technical information:
#     - original title _(original_title)_
#     - other titles _(also_known_as)_
#     - genres
#     - release year
#     - countries of origin
#     - duration
#     - release date in the country of origin (release_date_orig)
#     - release date in France _(release_date_france)_
#     - budget
#     - synopsis
# - People involved in the production:
#     - directors _(directors_link)_
#     - writers _(writers_link)_
#     - producers _(producers_link)_
#     - distributors _(distributors_link)_
#     - actors _(actors_link)_

# %%
film_technical_data = {}

film_tech_links_to_scrap = np.unique(df_films_overall['technical_info_link'])

for film in film_tech_links_to_scrap:
    url_film = link + film
    page_film = requests.get(url_film)
    soup_film = BeautifulSoup(page_film.content, "html.parser")

    print(film)
    # title = soup_film.find('h1', class_='Text__SCTitle-sc-1aoldkr-1 iTBZrv').text if soup_film.find('h1', class_='Text__SCTitle-sc-1aoldkr-1 iTBZrv') else None
    original_title = soup_film.find("span", string="Titre original : ").find_next_sibling(string=True) if soup_film.find("span", string="Titre original : ") else None
    aka = [aka.get_text(strip=True) for aka in soup_film.find("span", string="Aussi connu sous le nom de : ").find_next_siblings('span')] if soup_film.find("span", string="Aussi connu sous le nom de : ") else None
    genres = [genre.get_text(strip=True) for genre in soup_film.find("span", string=re.compile(r"Genres? : ")).find_next_siblings("a")] if soup_film.find("span", string=re.compile(r"Genres? : ")) else None
    year = soup_film.find('span', string='Année : ').find_next_sibling(string=True) if soup_film.find('span', string='Année : ') else None
    countries = [country.get_text(strip=True) for country in soup_film.find('span', string='Pays d\'origine : ').find_parent().find_next_siblings()] if soup_film.find('span', string='Pays d\'origine : ') else None
    duration = soup_film.find('span', string='Durée : ').find_next_sibling(string=True) if soup_film.find('span', string='Durée : ') else None
    release_pattern = re.compile(r"Date de sortie \((?!France)([^)]+)\) :")
    release_orig = soup_film.find('span', string=release_pattern).find_next_sibling(string=True) if soup_film.find('span', string=release_pattern) else None
    release_france = soup_film.find('span', string='Date de sortie (France) : ').find_next_sibling(string=True) if soup_film.find('span', string='Date de sortie (France) : ') else None
    directors_link = soup_film.find('span', string=re.compile(r"Réalisateurs? : ")).find_parent().find_next_sibling().get('href') if soup_film.find('span', string=re.compile(r"Réalisateurs? : ")) else None
    writers_link = [writers.get('href') for writers in soup_film.find('span', string=re.compile(r"Scénaristes? : ")).find_parent().find_next_siblings("a")] if soup_film.find('span', string=re.compile(r"Scénaristes? : ")) else None
    producers_link = [producers.get('href') for producers in soup_film.find('span', string=re.compile(r"Producteurs? : ")).find_parent().find_next_siblings("a")] if soup_film.find('span', string=re.compile(r"Producteurs? : ")) else None
    distributors_link = [distributors.get('href') for distributors in soup_film.find('span', string=re.compile(r"Distributeurs? : ")).find_parent().find_next_siblings("a")] if soup_film.find('span', string=re.compile(r"Distributeurs? : ")) else None
    actors_link = [actors.get('href') for actors in soup_film.find_all('a', class_= 'Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 gATBvI jacWTu')] if soup_film.find_all('a', class_= 'Text__SCText-sc-1aoldkr-0 Link__SecondaryLink-sc-1v081j9-1 gATBvI jacWTu') else None
    budget = soup_film.find('span', string='Budget : ').find_next_sibling(string=True) if soup_film.find('span', string='Budget : ') else None
    synopsis = soup_film.find('span', string='Synopsis : ').find_next_sibling(string=True) if soup_film.find('span', string='Synopsis : ') else None




    film_technical_data[film] = (
        # title,
        original_title,
        aka,
        genres,
        year,
        countries,
        duration,
        release_orig,
        release_france,
        directors_link,
        writers_link,
        producers_link,
        distributors_link,
        actors_link,
        budget,
        synopsis

    )
    
print(film_technical_data)
# Out:
# /film/andrei_roublev/372818/details
# /film/apocalypse_now/488421/details
# /film/barberousse/368097/details
# /film/blade_runner_the_final_cut/42244431/details
# /film/boulevard_du_crepuscule/465238/details
# /film/dersou_ouzala/479434/details
# /film/douze_hommes_en_colere/370894/details
# /film/entre_le_ciel_et_l_enfer/1324688/details
# /film/eve/448394/details
# /film/fenetre_sur_cour/407292/details
# /film/harakiri/402373/details
# /film/il_etait_une_fois_dans_l_ouest/440893/details
# /film/il_etait_une_fois_en_amerique/804173/details
# /film/jeux_dangereux/465400/details
# /film/l_aurore/451178/details
# /film/la_condition_de_l_homme_1_il_n_y_a_pas_de_plus_grand_amour/480277/details
# /film/la_femme_des_sables/409997/details
# /film/la_vie_est_belle/434210/details
# /film/le_bon_la_brute_et_le_truand/368376/details
# /film/le_chagrin_et_la_pitie/434213/details
# /film/le_dictateur/478657/details
# /film/le_parrain/408443/details
# /film/le_parrain_2e_partie/378648/details
# /film/le_tombeau_des_lucioles/486492/details
# /film/le_trou/440101/details
# /film/le_voyage_de_chihiro/1367079/details
# /film/les_affranchis/447001/details
# /film/les_enfants_du_paradis/384635/details
# /film/les_lumieres_de_la_ville/449464/details
# /film/les_sentiers_de_la_gloire/415777/details
# /film/les_sept_samourais/451324/details
# /film/les_temps_modernes/459866/details
# /film/m_le_maudit/380190/details
# /film/midsommar_the_director_s_cut/39872454/details
# /film/parasite/25357970/details
# /film/point_limite/461381/details
# /film/pour_sama/39231333/details
# /film/princesse_mononoke/376627/details
# /film/psychose/481802/details
# /film/pulp_fiction/445539/details
# /film/quand_passent_les_cigognes/438109/details
# /film/rebellion/442264/details
# /film/rendez_vous/470029/details
# /film/requiem_pour_un_massacre/404608/details
# /film/satantango_le_tango_de_satan/449796/details
# /film/sherlock_junior/494192/details
# /film/soy_cuba/390558/details
# /film/threat_level_midnight/449273/details
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/details
# /film/voyage_au_bout_de_l_enfer/376439/details
# {'/film/andrei_roublev/372818/details': ('Andrey Rublyov', ['Андрей Рублёв,', 'Andrei Rublev'], ['Drame', 'Biopic', 'Historique', 'Guerre'], '1966', ['Union Soviétique'], '3 h 03 min', '16 décembre 1966', 'décembre 1969', '/contact/Andrei_Tarkovski/2243', ['/contact/andrei_tarkovski/2243', '/contact/andrei_kontchalovski/2092'], ['/contact/Tamara_Ogorodnikova/5446128'], ['/contact/Baba_Yaga_Distribution/425038'], ['/contact/Anatoli_Solonitsyne/5072', '/contact/Ivan_Lapikov/11061', '/contact/Nikolai_Grinko/5073', '/contact/Nikolai_Sergeyev/96814', '/contact/Irma_Raush/1984026', '/contact/Nikolai_Bourliaiev/17390', '/contact/rolan_bykov/6227', '/contact/Yuri_Nazarov/20263', '/contact/tamara_ogorodnikova/5446128', '/contact/Ivan_Bykov/1375427'], '1 300 000 roubles', "En 1405, le peintre Théophane le Grec demande à Andreï Roublev de venir travailler avec lui à la décoration de l'église de l'Annonciation à Moscou. Quelques années plus tard, bouleversé par la violence de l'époque, Roublev renonce à son art et se mure dans le silence."), '/film/apocalypse_now/488421/details': (None, ["C'est l'apocalypse"], ['Drame', 'Guerre'], '1979', ['États-Unis'], '2 h 27 min', '15 août 1979', '26 septembre 1979', '/contact/Francis_Ford_Coppola/1387', ['/contact/John_Milius/12378', '/contact/francis_ford_coppola/1387'], ['/contact/John_Ashley/53124', '/contact/Kim_Aubry/53122', '/contact/Francis_Ford_Coppola/1387', '/contact/Gray_Frederickson/5447', '/contact/Shannon_Lail/53123', '/contact/Eddie_Romero/43246', '/contact/Fred_Roos/1538244', '/contact/Mona_Skager/5448', '/contact/Tom_Sternberg/5348175'], ['/contact/United_Artists/556452', '/contact/Gaumont_Buena_Vista_International_GBVI/422407'], ['/contact/marlon_brando/1529', '/contact/martin_sheen/8379', '/contact/robert_duvall/3100', '/contact/frederic_forrest/94', '/contact/sam_bottoms/3137', '/contact/laurence_fishburne/1392', '/contact/albert_hall/18225', '/contact/harrison_ford/994', '/contact/dennis_hopper/1603', '/contact/g_d_spradlin/8401'], '31 500 000 $', 'Durant la guerre du Viêt-nam, le capitaine Willard est contraint de mener une mission périlleuse au Cambodge. Accompagné de quatre soldats, il doit mettre fin au commandement du colonel Kurtz, qui utilise des méthodes jugées trop barbares.'), '/film/barberousse/368097/details': ('Akahige', ['赤ひげ'], ['Drame'], '1965', ['Japon'], '3 h 05 min', '3 avril 1965', '4 janvier 1978', '/contact/Akira_Kurosawa/1114', ['/contact/akira_kurosawa/1114', '/contact/masato_ide/495012', '/contact/ryuzo_kikushima/1128', '/contact/hideo_oguni/495014'], ['/contact/Akira_Kurosawa/1114', '/contact/Ryuzo_Kikushima/1128', '/contact/Tomoyuki_Tanaka/1180786'], ['/contact/Action_Cinemas_Theatre_du_Temple/422327'], ['/contact/toshiro_mifune/274', '/contact/Yuzo_Kayama/1115', '/contact/tsutomu_yamazaki/1126', '/contact/Reiko_Dan/1124', '/contact/Miyuki_Kuwano/1121', '/contact/kyoko_kagawa/1116', '/contact/Tatsuyoshi_Ehara/1123', '/contact/Terumi_Niki/1120', '/contact/Akemi_Negishi/1125', '/contact/yoshitaka_zushi/1119'], None, "Nous sommes à Koishikawa au XIX° siècle. Kyojio Niide, un médecin hargneux mais généreux, décide d'entraîner un jeune apprenti, Noboru Yasumoto."), '/film/blade_runner_the_final_cut/42244431/details': (None, ['Blade Runner : 25th-Anniversary Edition'], ['Science-fiction'], '2007', None, '1 h 57 min', '5 octobre 2007', '5 octobre 2007', '/contact/Ridley_Scott/573', ['/contact/david_webb_peoples/71045', '/contact/hampton_fancher/10636'], ['/contact/Charles_de_Lauzirika/543812'], None, ['/contact/harrison_ford/994', '/contact/rutger_hauer/4463', '/contact/sean_young/1591', '/contact/edward_james_olmos/10630', '/contact/m_emmet_walsh/8210', '/contact/daryl_hannah/10629', '/contact/william_sanderson/8906', '/contact/brion_james/9', '/contact/joe_turkel/5810', '/contact/joanna_cassidy/6714'], None, 'Dans les dernières années du 20ème siècle, des milliers d\'hommes et de femmes partent à la conquête de l\'espace, fuyant les mégalopoles devenues insa ...

# %%
df_films_tech = pd.DataFrame.from_dict(film_technical_data, 
                                      orient='index', 
                                      columns=[
                                        #   'title',
                                          'original_title',
                                          'also_known_as',
                                          'genres',
                                          'release_year',
                                          'countries_of_origin',
                                          'duration',
                                          'release_date_orig',
                                          'release_date_france',
                                          'directors_link',
                                          'writers_link',
                                          'producers_link',
                                          'distributors_link',
                                          'actors_link',
                                          'budget',
                                          'synopsis'
                                          ]
                                          )

df_films_tech.tail()
# Out:
#                                                                      original_title  \
# /film/sherlock_junior/494192/details                                   Sherlock Jr.
# /film/soy_cuba/390558/details                                                  None
# /film/threat_level_midnight/449273/details                                     None
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...  One Flew Over the Cuckoo's Nest
# /film/voyage_au_bout_de_l_enfer/376439/details                      The Deer Hunter
#
#                                                                        also_known_as  \
# /film/sherlock_junior/494192/details                                            None
# /film/soy_cuba/390558/details                       [I Am Cuba,, Ya Kuba,, Я - Куба]
# /film/threat_level_midnight/449273/details                                      None
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...                              None
# /film/voyage_au_bout_de_l_enfer/376439/details                                  None
#
#                                                                               genres  \
# /film/sherlock_junior/494192/details                [Muet, Comédie, Action, Romance]
# /film/soy_cuba/390558/details                                                [Drame]
# /film/threat_level_midnight/449273/details                                 [Comédie]
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...       [Drame, Comédie dramatique]
# /film/voyage_au_bout_de_l_enfer/376439/details                       [Drame, Guerre]
#
#                                                    release_year  \
# /film/sherlock_junior/494192/details                       1924
# /film/soy_cuba/390558/details                              1964
# /film/threat_level_midnight/449273/details                 2011
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...         1975
# /film/voyage_au_bout_de_l_enfer/376439/details             1978
#
#                                                            countries_of_origin  \
# /film/sherlock_junior/494192/details                              [États-Unis]
# /film/soy_cuba/390558/details                        [Cuba,, Union Soviétique]
# /film/threat_level_midnight/449273/details                        [États-Unis]
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...                [États-Unis]
# /film/voyage_au_bout_de_l_enfer/376439/details      [États-Unis,, Royaume-Uni]
#
#                                                       duration  \
# /film/sherlock_junior/494192/details                    45 min
# /film/soy_cuba/390558/details                       2 h 21 min
# /film/threat_level_midnight/449273/details              30 min
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...  2 h 13 min
# /film/voyage_au_bout_de_l_enfer/376439/details      3 h 03 min
#
#                                                    release_date_orig  \
# /film/sherlock_junior/494192/details                     11 mai 1924
# /film/soy_cuba/390558/details                        26 octobre 1964
# /film/threat_level_midnight/449273/details                      None
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...  21 novembre 1975
# /film/voyage_au_bout_de_l_enfer/376439/details       8 décembre 1978
#
#                                                    release_date_france  \
# /film/sherlock_junior/494192/details                   28 octobre 1924
# /film/soy_cuba/390558/details                          16 juillet 2003
# /film/threat_level_midnight/449273/details             17 février 2011
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...         1 mars 1976
# /film/voyage_au_bout_de_l_enfer/376439/details             7 mars 1979
#
#                                                                       directors_link  \
# /film/sherlock_junior/494192/details                     /contact/Buster_Keaton/5696
# /film/soy_cuba/390558/details                       /contact/Mikhail_Kalatozov/10915
# /film/threat_level_midnight/449273/details             /contact/Tucker_Gates/1110101
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...         /contact/Milos_Forman/614
# /film/voyage_au_bout_de_l_enfer/376439/details          /contact/Michael_Cimino/5885
#
#                                                                                          writers_link  \
# /film/sherlock_junior/494192/details                                                             None
# /film/soy_cuba/390558/details                       [/contact/Enrique_Pineda_Barnet/123498, /conta...
# /film/threat_level_midnight/449273/details          [/contact/greg_daniels/275178, /contact/b_j_no...
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...  [/contact/Lawrence_Hauben/35309, /contact/Bo_G...
# /film/voyage_au_bout_de_l_enfer/376439/details                      [/contact/Deric_Washburn/1535256]
#
#                                                                                        producers_link  \
# /film/sherlock_junior/494192/details                [/contact/Buster_Keaton/5696, /contact/Joseph_...
# /film/soy_cuba/390558/details                                                                    None
# /film/threat_level_midnight/449273/details                                                       None
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...  [/contact/Michael_Douglas/525, /contact/Saul_Z...
# /film/voyage_au_bout_de_l_enfer/376439/details      [/contact/Michael_Cimino/5885, /contact/Michae...
#
#                                                                                     distributors_link  \
# /film/sherlock_junior/494192/details                                 [/contact/Splendor_Films/422618]
# /film/soy_cuba/390558/details                       [/contact/MK2_Diffusion/422298, /contact/Potem...
# /film/threat_level_midnight/449273/details                                                       None
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...                   [/contact/United_Artists/556452]
# /film/voyage_au_bout_de_l_enfer/376439/details                       [/contact/Carlotta_Films/422349]
#
#                                                                                           actors_link  \
# /film/sherlock_junior/494192/details                [/contact/buster_keaton/5696, /contact/kathryn...
# /film/soy_cuba/390558/details                       [/contact/Sergio_Corrieri/21087, /contact/Salv...
# /film/threat_level_midnight/449273/details          [/contact/steve_carell/72401, /contact/rainn_w...
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...  [/contact/jack_nicholson/2, /contact/louise_fl...
# /film/voyage_au_bout_de_l_enfer/376439/details      [/contact/robert_de_niro/13, /contact/john_caz...
#
#                                                           budget  \
# /film/sherlock_junior/494192/details                        None
# /film/soy_cuba/390558/details                               None
# /film/threat_level_midnight/449273/details                  None
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...    $4 400 000
# /film/voyage_au_bout_de_l_enfer/376439/details      15 000 000 $
#
#                                                                                              synopsis
# /film/sherlock_junior/494192/details                Un projectionniste, qui rêve d'être détective,...
# /film/soy_cuba/390558/details                       A travers quatre histoires, "Soy Cuba" décrit ...
# /film/threat_level_midnight/449273/details          Après 11 ans de préparation, Michael Scott nou...
# /film/vol_au_dessus_d_un_nid_de_coucou/447958/d...  Pour échapper à la prison, Randall P. McMurphy...
# /film/voyage_au_bout_de_l_enfer/376439/details      Une analyse en profondeur de la façon dont la ...

# %% [markdown]
# For People involved in the production, save their:
# - Technical information:
#     - name _(person_name)_
#     - description
#     - how many people liked them _(likes)_

# %%
people_data = {}
unique_values = set()

for column in ['directors_link', 'writers_link', 'producers_link', 'distributors_link', 'actors_link']:
    for cell in df_films_tech[column]:
        if isinstance(cell, list):
            unique_values.update(cell)
        if isinstance(cell, str):
            unique_values.add(cell)

people_links_to_scrape = list(unique_values)

for person in people_links_to_scrape:
    print(person)
    url_person = link + person
    page_person = requests.get(url_person)
    soup_person = BeautifulSoup(page_person.content, "html.parser")

    person_name = soup_person.find('h1', class_="Text__SCTitle-sc-1aoldkr-1").text
    description = soup_person.find('p', class_="CoverContactInfos__Description-sc-1402al5-8").text
    likes = soup_person.find('p', class_=lambda x: x and x.startswith("Text__SCText-sc-1aoldkr-0 Stats__Text-sc-1u6v943-2 gATBvI")).text

    people_data[person] = (person_name, description, likes)
    
print(people_data)
# Out:
# /contact/nicholas_pileggi/96787
# /contact/Emmanuel_d_Astier_de_la_Vigerie/4892844
# /contact/Jean_Keraudy/7054
# /contact/Saiichiro_Ujie/5446136
# /contact/Albert_S_Ruddy/9255
# /contact/Ernst_Lubitsch/38
# /contact/george_davis/5973
# /contact/Ivan_Bykov/1375427
# /contact/Martin_Balsam/3627
# /contact/john_krasinski/84703
# /contact/harrison_ford/994
# /contact/henry_daniell/486
# /contact/erwin_connelly/1355845
# /contact/Splendor_Films/422618
# /contact/Melchior_Lengyel/501151
# /contact/kathryn_mc_guire/8734
# /contact/tim_roth/17693
# /contact/Marc_Michel/3919
# /contact/Anatoli_Solonitsyne/5072
# /contact/Liubomiras_Lauciavicius/1179265
# /contact/james_stewart/970
# /contact/brad_dourif/1589
# /contact/Irma_Raush/1984026
# /contact/akira_ishihama/98233
# /contact/tetsuro_tamba/505977
# /contact/Action_Cinemas_Theatre_du_Temple/422327
# /contact/sean_young/1591
# /contact/celeste_holm/9067
# /contact/ari_aster/896473
# /contact/Ivan_Lapikov/11061
# /contact/rutger_hauer/4463
# /contact/erich_von_stroheim/2913
# /contact/Akemi_Yamaguchi/31652
# /contact/Jean_Paul_Coquelin/1196760
# /contact/Stacey_Sher/1538238
# /contact/Celia_Rodriguez/1414518
# /contact/Ross_Bagdasarian/117675
# /contact/Mikhail_Kalatozov/10915
# /contact/carole_lombard/2761
# /contact/louise_fletcher/11016
# /contact/Mifune_Productions_Co_Ltd/520396
# /contact/carl_mayer/495403
# /contact/Fausto_Mirabal/5186538
# /contact/will_sampson/11003
# /contact/uma_thurman/19453
# /contact/Les_Films_du_Paradoxe/493873
# /contact/lee_sun_kyun/128195
# /contact/Marcel_Carne/499
# /contact/Janos_Derzsi/24754
# /contact/Rutanya_Alda/22894
# /contact/Bac_Films/422270
# /contact/frances_goodrich/494787
# /contact/Christian_de_la_Maziere/538088
# /contact/Luz_Maria_Collazo/74773
# /contact/Enrique_Pineda_Barnet/123498
# /contact/George_Justin/5005770
# /contact/Arnon_Milchan/1155311
# /contact/philippe_dumat/2466
# /contact/Fred_Orain/1672
# /contact/Eiko_Yoshida/5715540
# /contact/Frank_Morgan/4924
# /contact/jun_tazaki/20726
# /contact/richard_alexander/4579
# /contact/billy_gilbert/7476
# /contact/harry_myers/11755
# /contact/go_kato/25330
# /contact/shima_iwashita/6486
# /contact/adolphe_menjou/2204
# /contact/James_Hayden/8823
# /contact/frank_capra/7646
# /contact/laurence_fishburne/1392
# /contact/Michael_Douglas/525
# /contact/grace_hayle/11742
# /contact/masato_ide/495012
# /contact/otto_wernicke/3382
# /contact/raymond_burr/6456
# /contact/Lee_Van_Cleef/2232
# /contact/sen_yano/26787
# /contact/Chuck_Low/11326
# /contact/Yutaka_Narita/1938640
# /contact/elem_klimov/4807
# /contact/fritz_lang/1273
# /contact/Michael_Shamberg/1538208
# /contact/larry_j_blake/30072
# /contact/jack_reynor/1144617
# /contact/Takeyoshi_Matsushita/80888
# /contact/MK2_Diffusion/422298
# /contact/arthur_housman/35888
# /contact/sergio_leone/3267
# /contact/rada_rassimov/31088
# /contact/James_B_Harris/2043
# /contact/h_b_warner/5697
# /contact/larry_hagman/5901
# /contact/john_travolta/4377
# /contact/Theatre_du_Temple_Distribution/5760693
# /contact/Eugene_Burdick/1601273
# /contact/Toru_Hara/63502
# /contact/koji_nanbara/505978
# /contact/keiji_sada/6478
# /contact/Koba_Hayashi/1214367
# /contact/Eijiro_Hisaita/502499
# /contact/andre_chaumeau/10582
# /contact/anne_baxter/9066
# /contact/masao_mishima/3620
# /contact/Siobhan_Sinnerton/2509633
# /contact/kamatari_fujiwara/1117
# /contact/Ayano_Shiraishi/31650
# /contact/pierre_renoir/1660
# /contact/Alfred_Hitchcock/2622
# /contact/Eddie_Romero/43246
# /contact/frank_wolff/639
# /contact/Michael_Cimino/5885
# /contact/Salvador_Wood/60003
# /contact/gary_merrill/9068
# /contact/woody_strode/1412
# /contact/Enzo_Petito/1195266
# /contact/John_Ashley/53124
# /contact/henry_fonda/6117
# /contact/Bo_Goldman/496203
# /contact/Chuck_Aspegren/59966
# /contact/charles_brackett/5701
# /contact/sam_bottoms/3137
# /contact/Yuri_Solomin/543608
# /contact/john_marley/642
# /contact/park_myoung_hoon/1751731
# /contact/danny_aiello/1252
# /contact/Tom_Sternberg/5348175
# /contact/Gray_Frederickson/5447
# /contact/eli_wallach/1023
# /contact/yoshio_kosugi/5115
# /contact/Tatsuo_Hosoya/2907582
# /contact/catherine_sola/19839
# /contact/Viktor_Lorents/1179267
# /contact/Patricia_Hitchcock/9094
# /contact/Nikolai_Bourliaiev/17390
# /contact/Michael_Deeley/5446312
# /contact/bong_joon_ho/75706
# /contact/jose_gallardo/74774
# /contact/Toshio_Suzuki/63484
# /contact/Erzsebet_Gaal/40039
# /contact/jim_thompson/27762
# /contact/ryuzo_kikushima/1128
# /contact/greg_daniels/275178
# /contact/toshiro_mifune/274
# /contact/Harry_Crocker/12269
# /contact/Thomas_Benski/2751479
# /contact/Maurice_Moscovitch/14234
# /contact/Laszlo_fe_Lugossy/1414162
# /contact/D_M_Marshman_Jr/501141
# /contact/Franco_Arcalli/38837
# /contact/yuriy_nagibin/1510972
# /contact/Ridley_Scott/573
# /contact/Igor_Sykhra/5004985
# /contact/charles_bronson/1821
# /contact/Yuri_Nazarov/20263
# /contact/Deric_Washburn/1535256
# /contact/thelma_ritter/6455
# /contact/danny_de_vito/527
# /contact/michael_v_gazzo/9228
# /contact/fritz_odemar/115727
# /contact/john_bartha/44703
# /contact/robert_bloch/163017
# /contact/sarah_edwards/8588
# /contact/miklos_szekely_b/1293283
# /contact/Yoshiko_Shinohara/31651
# /contact/Les_Acacias/422507
# /contact/Billy_Wilder/861
# /contact/Danny_DeVito/527
# /contact/Alberto_Morgan/5186537
# /contact/Ben_de_Pear/5112815
# /contact/george_dzundza/22461
# /contact/john_cazale/9182
# /contact/Gloria_Swanson/5488
# /contact/paul_sorvino/4340
# /contact/hideo_oguni/495014
# /contact/b_j_novak/91341
# /contact/jack_klugman/17861
# /contact/kaoru_kobayashi/69567
# /contact/Vladimir_Sergiyakov/5004986
# /contact/tuesday_weld/9129
# /contact/G_Velts/1179270
# /contact/Gyoergy_Barko/40041
# /contact/Yuzo_Kayama/1115
# /contact/Vilhelm_Blomgren/4918757
# /contact/Hiroshi_Teshigahara/3929
# /contact/Nevine_Mabro/5112816
# /contact/samuel_l_jackson/5373
# /contact/Raul_Garcia/3226987
# /contact/Elem_Klimov/4807
# /contact/Henrik_Norlen/519388
# /contact/inge_landgut/3385
# /contact/henry_travers/13007
# /contact/hideo_kanze/15311
# /contact/Svetlana_Kharitonova/10919
# /contact/Valentin_Zubkov/98516
# /contact/Juri_Lumiste/1179266
# /contact/anthony_perkins/2409
# /contact/Carlotta_Films/422349
# /contact/archie_madekwe/2850900
# /contact/john_fiedler/17860
# /contact/Gaumont_Buena_Vista_International_GBVI/422407
# /contact/ralph_meeker/9158
# /contact/Tsutomu_Tatsumi/31649
# /contact/Georgine_Darcy/2592375
# /contact/cedric_dumond/87623
# /contact/Grace_Kelly/2194
# /contact/Friedrich_Wilhelm_Murnau/942
# /contact/kyoko_kagawa/1116
# /contact/Tadashi_Ono/5715539
# /contact/vera_miles/9091
# /contact/sydney_lassick/32102
# /contact/Gregory_Ratoff/9069
# /contact/albert_hackett/494786
# /contact/Kwak_Sinae/5004692
# /contact/Ryuzo_Kikushima/1128
# /contact/Toho/513767
# /contact/peter_lorre/3381
# /contact/tatiana_samoilova/10897
# /contact/charles_halton/2767
# /contact/bruce_willis/9167
# /contact/shinobu_hashimoto/32163
# /contact/Marcel_Ophuls/14799
# /contact/tatsuya_mihashi/33235
# /contact/simon_oakland/3982
# /contact/Tucker_Gates/1110101
# /contact/fabien_loris/1662
# /contact/emma_dunn/17780
# /contact/Barry_Spikings/31541
# /contact/jack_elam/4552
# /contact/edward_james_olmos/10630
# /contact/Yo_Oizumi/79372
# /contact/sig_ruman/2765
# /contact/Mona_Skager/5448
# /contact/Waad_AlKateab/5112813
# /contact/joseph_l_mankiewicz/5320
# /contact/andrei_kontchalovski/2092
# /contact/Reginald_Rose/17868
# /contact/Barbara_De_Fina/1181632
# /contact/gabriele_ferzetti/4909
# /contact/russell_hardie/551046
# /contact/albert_hall/18225
# /contact/Buena_Vista_International/422266
# /contact/Ari_Aster/896473
# /contact/Wendell_Corey/6454
# /contact/billy_wilder/861
# /contact/gustaf_grundgens/3383
# /contact/Hamza_Al_Kateab/5112811
# /contact/edwin_maxwell/2567
# /contact/takeshi_kato/69321
# /contact/thea_von_harbou/495257
# /contact/Matthaeus_Bleibinger/4892841
# /contact/livio_lorenzon/15165
# /contact/frederic_forrest/94
# /contact/Sojiro_Motoki/1423584
# /contact/Sara_Haden/4926
# /contact/Terumi_Niki/1120
# /contact/Nikolai_Grinko/5073
# /contact/michel_constantin/5525
# /contact/clint_eastwood/2888
# /contact/boris_kokovkin/1260667
# /contact/amanda_plummer/25646
# /contact/richard_conte/8977
# /contact/Lee_J_Cobb/3063
# /contact/Tamotsu_Tamura/26791
# /contact/Adele_Carasso/535448
# /contact/hampton_fancher/10636
# /contact/friedrich_gnass/1338510
# /contact/marlon_brando/1529
# /contact/reginald_gardiner/9314
# /contact/Lawrence_Hauben/35309
# /contact/paulette_goddard/10041
# /contact/lorraine_bracco/16235
# /contact/francis_ford_coppola/1387
# /contact/ward_crane/12334
# /contact/Reiko_Dan/1124
# /contact/keenan_wynn/1822
# /contact/michiyo_aratama/6481
# /contact/aleksey_kravchenko/545520
# /contact/Connaissance_du_Cinema/422889
# /contact/Carter_De_Haven/10702
# /contact/Pierre_Segui/1109124
# /contact/Pathe_Cinema/424073
# /contact/elizabeth_mc_govern/5371
# /contact/Felix_Bressart/2764
# /contact/ineko_arima/22061
# /contact/Judith_Evelyn/6457
# /contact/jung_ji_so/1841596
# /contact/ed_helms/86148
# /contact/Enrico_Medioli/282198
# /contact/isao_kimura/1364
# /contact/Sidney_Lumet/7800
# /contact/ward_bond/3469
# /contact/V_Lastochkin/5004983
# /contact/yuko_tanaka/10428
# /contact/Han_Jin_Won/5011029
# /contact/herman_bing/4635
# /contact/Charles_Brackett/5701
# /contact/aldo_giuffre/23826
# /contact/Baba_Yaga_Distribution/425038
# /contact/Florence_Lee/11756
# /contact/isao_yamagata/10434
# /contact/KMBO/424493
# /contact/janet_leigh/349
# /contact/mario_puzo/163504
# /contact/Pelle_Nilsson/5028017
# /contact/Ben_Rimmer/128809
# /contact/eric_stoltz/29917
# /contact/Jerome_Pauwels/75838
# /contact/Akira_Kurosawa/1114
# /contact/frank_albertson/9093
# /contact/Martin_Fink/11018
# /contact/Vladimir_Khrulyov/5004982
# /contact/Wayne_Morris/19264
# /contact/micky_sebastian/27711
# /contact/palau/12603
# /contact/stanley_kubrick/1129
# /contact/Bob_Weinstein/1155309
# /contact/etsuko_ichihara/20888
# /contact/Donald_W_Ernst/28754
# /contact/franco_ferrini/93165
# /contact/Jacques_Becker/7028
# /contact/harvey_keitel/15
# /contact/j_farrell_mac_donald/947
# /contact/Banjiro_Uemura/2300423
# /contact/Viktoria_Petranyi/99768
# /contact/hank_mann/11790
# /contact/quentin_tarantino/26764
# /contact/brion_james/9
# /contact/martin_sheen/8379
# /contact/Rene_de_Chambrun/4892845
# /contact/rolan_bykov/6227
# /contact/seiji_miyaguchi/2569
# /contact/kirk_douglas/6246
# /contact/john_michael_hayes/494866
# /contact/Raymond_Borderie/2421103
# /contact/gaston_modot/1667
# /contact/Miyuki_Kuwano/1121
# /contact/luigi_pistilli/6201
# /contact/dennis_hopper/1603
# /contact/koji_mitsui/23817
# /contact/jenna_fischer/106764
# /contact/john_gavin/9090
# /contact/Hayao_Miyazaki/31665
# /contact/Dan_O_Herlihy/14384
# /contact/Irwin_Winkler/4881
# /contact/g_d_spradlin/8401
# /contact/Francis_Ford_Coppola/1387
# /contact/daryl_hannah/10629
# /contact/Fredrik_Heinig/3114031
# /contact/jerry_hausner/19266
# /contact/raymond_meunier/7053
# /contact/United_Artists/556452
# /contact/bunta_sugawara/72124
# /contact/richard_bright/1872
# /contact/Inez_Courtney/4927
# /contact/Patrik_Andersson/3588099
# /contact/Lawrence_Bender/2990
# /contact/frank_sivero/9254
# /contact/Ellen_Widmann/3384
# /contact/aleksandr_shvorin/542865
# /contact/Charles_Braun/4892842
# /contact/sterling_hayden/3887
# /contact/Said_Amadis/698
# /contact/richard_anderson/17036
# /contact/Akemi_Negishi/1125
# /contact/jane_winton/1179259
# /contact/Yoichi_Matsue/1328368
# /contact/Virginia_Cherrill/11754
# /contact/david_webb_peoples/71045
# /contact/aleksey_batalov/1128165
# /contact/margaret_livingston/1179257
# /contact/stanley_ridges/521
# /contact/Richard_N_Gladstein/26766
# /contact/Mosfilm/520485
# /contact/Richard_S_Castellano/1220665
# /contact/marilyn_monroe/3001
# /contact/lionel_atwill/1758
# /contact/takamaru_sasaki/9009
# /contact/jane_connelly/5855205
# /contact/hisashi_igawa/15299
# /contact/will_poulter/117379
# /contact/ray_liotta/20707
# /contact/isao_takahata/31648
# /contact/bette_davis/1265
# /contact/philippe_leroy/7055
# /contact/joseph_schildkraut/4925
# /contact/Studio_Ghibli/195431
# /contact/George_Lynn/8633
# /contact/Andrei_Tarkovski/2243
# /contact/Harvey_Weinstein/2993
# /contact/Alberto_Grimaldi/5306097
# /contact/Kiyohiko_Ichihara/26789
# /contact/phil_la_marr/78762
# /contact/Walter_Bernstein/65400
# /contact/john_savage/1867
# /contact/jack_nicholson/2
# /contact/al_pacino/4335
# /contact/mari_natsuki/35421
# /contact/henry_bergman/10042
# /contact/jacques_becker/7028
# /contact/meryl_streep/14
# /contact/william_hansen/7207
# /contact/frank_vincent/6308
# /contact/john_mc_intire/3163
# /contact/Robert_Evans/1433
# /contact/Saul_Zaentz/625
# /contact/fritz_weaver/27893
# /contact/chikage_awashima/19022
# /contact/Fulvio_Morsella/10844
# /contact/eddie_boland/73847
# /contact/mike_starr/8820
# /contact/Ellora_Torchia/2123800
# /contact/Shigeru_Wakatsuki/2131676
# /contact/e_g_marshall/3330
# /contact/diane_keaton/756
# /contact/jang_hye_jin/4085102
# /contact/Takashi_Naito/46778
# /contact/Les_Grands_Films_Classiques/422417
# /contact/tsutomu_yamazaki/1126
# /contact/tatsuya_nakadai/6330
# /contact/Fritz_Lang/1273
# /contact/virginie_mery/42236
# /contact/Rumi_Hiiragi/69348
# /contact/Sama_Al_Kateab/5112812
# /contact/bodil_rosing/946
# /contact/Harry_Carr/5257014
# /contact/leonardo_benvenuti/494438
# /contact/Paramount_Pictures/422928
# /contact/jack_webb/5700
# /contact/fred_clark/5699
# /contact/Iren_Szajki/40037
# /contact/lionel_barrymore/12126
# /contact/Isao_Takahata/31648
# /contact/tsunehiko_kamijo/1214368
# /contact/james_caan/4820
# /contact/yoko_tsukasa/6476
# /contact/yoshio_inaba/2568
# /contact/franklyn_farnum/3825
# /contact/Isabelle_Grill/5028006
# /contact/lee_jung_eun/2934520
# /contact/eva_almassy_albert/40036
# /contact/Yanis_Yakobsons/5004987
# /contact/Brian_Baumgartner/105165
# /contact/rainn_wilson/54016
# /contact/florence_pugh/2906888
# /contact/jean_bouise/932
# /contact/Jacques_Doriot/4892847
# /contact/Olga_Mironova/13469
# /contact/Antonina_Bogdanova/1127246
# /contact/andrei_tarkovski/2243
# /contact/Frank_Capra/7646
# /contact/sergio_donati/493367
# /contact/Kiichi_Ichikawa/2269196
# /contact/Charles_H_Maguire/652
# /contact/frank_cady/6459
# /contact/Charles_Dayton/1321543
# /contact/Seiichiro_Ujiie/60389
# /contact/lee_strasberg/4652
# /contact/Fred_Roos/1538244
# /contact/Putyi_Horvath/1414161
# /contact/Lloyd_Gough/5363
# /contact/maria_casares/1658
# /contact/Gloria_Grahame/2050
# /contact/tatsuo_matsumura/27802
# /contact/tiny_sandford/953167
# /contact/piero_de_bernardi/494439
# /contact/Al_Lettieri/9230
# /contact/William_Fox/4696935
# /contact/Kazimir_Rabetsky/1179268
# /contact/claudia_cardinale/957
# /contact/luciano_vincenzoni/64043
# /contact/tom_dugan/2766
# /contact/eiji_okada/12386
# /contact/Gyorgy_Feher/1382501
# /contact/stanley_blystone/109236
# /contact/Cine_Classic/422324
# /contact/Evgeniy_Evtushenko/3015618
# /contact/Frank_Faylen/6412
# /contact/Stanislav_Marin/5004984
# /contact/Joseph_L_Mankiewicz/5320
# /contact/Edward_Binns/9166
# /contact/Vladas_Bagdonas/13472
# /contact/joe_keaton/8831
# /contact/Joseph_Stefano/277268
# /contact/John_Lasseter/37339
# /contact/christiane_kubrick/19265
# /contact/jason_robards/6837
# /contact/ed_begley/4165
# /contact/gunnel_fred/88645
# /contact/Leslie_David_Baker/55908
# /contact/Paul_Kemp/62517
# /contact/John_Peverall/59968
# /contact/Maksim_Munzuk/1510971
# /contact/Russell_Collins/6212
# /contact/christine_francis/5855206
# /contact/buster_keaton/5696
# /contact/m_emmet_walsh/8210
# /contact/kyoko_kishida/22329
# /contact/Serge_Silberman/4923919
# /contact/choi_woo_sik/1759236
# /contact/Aleksandr_Berda/502746
# /contact/toru_takeuchi/1442540
# /contact/Konstantin_Kadochnikov/1260666
# /contact/Raney_Aronson/2667379
# /contact/James_Woods/9738
# /contact/Samson_Raphaelson/198609
# /contact/tony_darrow/23133
# /contact/Buster_Keaton/5696
# /contact/marcel_herrand/25
# /contact/Tamara_Ogorodnikova/5446128
# /contact/Nikolai_Sergeyev/96814
# /contact/Waad_Al_Kateab/5112813
# /contact/Vasiliy_Merkurev/1260665
# /contact/Max_E_Youngstein/4864064
# /contact/George_Mac_Ready/3795
# /contact/Sergio_Leone/3267
# /contact/Joseph_M_Schenck/4864983
# /contact/George_Sanders/4309
# /contact/Joachim_Von_Vietinghoff/40049
# /contact/Les_Bookmakers/3564523
# /contact/Hironori_Aihara/80891
# /contact/Quentin_Tarantino/26764
# /contact/Nancy_Olson/5698
# /contact/minoru_chiaki/2570
# /contact/ichiro_nakatani/527694
# /contact/william_redfield/7307
# /contact/Kim_Aubry/53122
# /contact/Sergio_Corrieri/21087
# /contact/barbara_bates/9070
# /contact/marcel_peres/1666
# /contact/christopher_walken/759
# /contact/Milos_Forman/614
# /contact/talia_shire/9231
# /contact/theo_lingen/3388
# /contact/Bong_JoonHo/75706
# /contact/Jack_Oakie/4229
# /contact/Ekaterina_Kupriyanova/1260668
# /contact/Roberto_Garcia_York/5186539
# /contact/joe_pesci/6303
# /contact/Georges_Bidault/84729
# /contact/Masaki_Kobayashi/20521
# /contact/Emile_Coulaudon/4892843
# /contact/calder_willingham/495941
# /contact/ving_rhames/9812
# /contact/Seymour_Nebenzal/4284989
# /contact/Hugh_Marlowe/3232
# /contact/robert_duvall/3100
# /contact/charlie_chaplin/10040
# /contact/ernesto_gastaldi/78738
# /contact/jack_benny/2762
# /contact/John_Milius/12378
# /contact/Margaret_Sullavan/4923
# /contact/Toshiro_Mifune/274
# /contact/Miky_Lee/1769237
# /contact/chester_conklin/3814
# /contact/keiko_tsushima/32571
# /contact/George_Waldrum/2509636
# /contact/william_tracy/68530
# /contact/creed_bratton/521427
# /contact/joanna_cassidy/6714
# /contact/jack_warden/4650
# /contact/Lars_Knudsen/1705687
# /contact/jean_louis_barrault/1656
# /contact/so_yamamura/6470
# /contact/song_kang_ho/44765
# /contact/Claudio_Scarchilli/15174
# /contact/treat_williams/1868
# /contact/Eddy_Rasimi/132974
# /contact/Mihaly_Vig/923741
# /contact/Tomoyuki_Tanaka/1180786
# /contact/Miyu_Irino/69349
# /contact/Philip_Westgren/4905976
# /contact/tatsuya_gashuin/79370
# /contact/Cocinor/422583
# /contact/george_o_brien/943
# /contact/jacques_prevert/11867
# /contact/Darryl_F_Zanuck/3228
# /contact/Shannon_Lail/53123
# /contact/andre_bervil/7058
# /contact/steve_carell/72401
# /contact/shirley_stoler/20425
# /contact/Park_MyeongChan/1153593
# /contact/Edwin_Justus_Mayer/497279
# /contact/william_sanderson/8906
# /contact/Cecil_Reynolds/1229189
# /contact/arletty/501
# /contact/christopher_lloyd/7
# /contact/Dean_R_Brooks/1254020
# /contact/theodor_loos/2138
# /contact/Moon_YangKwon/520230
# /contact/ralph_sipperly/1179258
# /contact/ryunosuke_kamiki/79371
# /contact/betsy_ann_hisle/1383051
# /contact/Carter_DeHaven/10702
# /contact/Laszlo_Krasznahorkai/168398
# /contact/Martin_Scorsese/2101
# /contact/tamara_ogorodnikova/5446128
# /contact/Cho_Yeo_Jeong/132525
# /contact/william_holden/5694
# /contact/robert_de_niro/13
# /contact/Vaughn_Taylor/9092
# /contact/Peter_Capell/19267
# /contact/paolo_stoppa/9337
# /contact/park_so_dam/2362599
# /contact/Maurice_Buckmaster/85413
# /contact/thomas_mitchell/6695
# /contact/akira_kurosawa/1114
# /contact/jun_hamamura/8460
# /contact/joe_turkel/5810
# /contact/daisuke_kato/2571
# /contact/Mikhail_Bychkov/5004981
# /contact/robert_stack/2763
# /contact/pierre_brasseur/1657
# /contact/Koji_Hoshino/425270
# /contact/Louis_Darquier_de_Pellepoix/4892846
# /contact/william_duell/59760
# /contact/jeong_hyun_jun/5011025
# /contact/takashi_shimura/1359
# /contact/janet_gaynor/944
# /contact/roger_avary/31799
# /contact/Tatsuyoshi_Ehara/1123
# /contact/donna_reed/11597
# /contact/doris_deane/545737
# /contact/beulah_bondi/13228
# /contact/sara_berner/6458
# /contact/Charlie_Chaplin/10040
# /contact/V_Khlestov/5004988
# /contact/Cinedis/423900
# /contact/jean_becker/7056
# /contact/Joseph_Sweeney/17863
# /contact/burt_young/10476
# /contact/Bela_Tarr/14656
# /contact/Al_Ernest_Garcia/10043
# /contact/Ales_Adamovich/496607
# /contact/Henry_Fonda/6117
# /contact/Ruth_Waldburger/14875
# /contact/Hiroko_Ito/26786
# /contact/yoshitaka_zushi/1119
# /contact/Viktor_Rozov/499773
# /contact/william_jackson_harper/2014148
# /contact/Alfred_Jarai/40038
# /contact/Yevgeni_Tilicheyev/1179269
# /contact/kei_sato/8464
# /contact/jose_giovanni/14776
# /contact/Zenzo_Matsuyama/501174
# /contact/Stuart_Kaminsky/215791
# /contact/Jang_YoungHwan/4812336
# /contact/The_Jokers/1578320
# /contact/craig_robinson/105750
# /contact/Claudio_Mancini/6118
# /contact/Yukiko_Shimazaki/19039
# /contact/Bruce_S_Pustin/23144
# /contact/Walter_Matthau/4842
# /contact/Potemkine_Films/1126663
# /contact/kenjiro_ishiyama/32253
# /contact/frank_overton/20586
# /contact/Stanley_Kubrick/1129
# /contact/Nobuo_Nakamura/6480
# /contact/Hiroyuki_Nishimoto/26790
# /contact/Charles_de_Lauzirika/543812
# /contact/Ginzo_Sekiguchi/26788
# /contact/Bino_Cicogna/51656
# {'/contact/nicholas_pileggi/96787': ('Nicholas Pileggi', 'acteur, auteur, producteur et scénariste américain/italien né le 22 février 1933 à New York City.', '6 aiment'), '/contact/Emmanuel_d_Astier_de_la_Vigerie/4892844': ("Emmanuel d'Astier de la Vigerie", 'acteur.', '0'), '/contact/Jean_Keraudy/7054': ('Jean Keraudy', 'acteur français né le 19 avril 1920 à Billancourt. Il est décédé le 30 septembre 2001 à Cravent.', '24 aiment'), '/contact/Saiichiro_Ujie/5446136': ('Saiichiro Ujie', 'producteur.', '0'), '/contact/Albert_S_Ruddy/9255': ('Albert S. Ruddy', 'acteur, auteur, producteur et scénariste.', '1 aime'), '/contact/Ernst_Lubitsch/38': ('Ernst Lubitsch', 'acteur, auteur, réalisateur, producteur et scénariste américain né le 27 janvier 1892 à Berlin (Allemagne). Il est décédé le 29 novembre 1947 à Los Angeles.', '572 aiment'), '/contact/george_davis/5973': ('George Davis', 'acteur, artiste musical et producteur américain né le 6 novembre 1889 à Amsterdam (Pays-Bas). Il est décédé le 18 avril 1965 à Los Angeles.', '1 aime'), '/contact/Ivan_Bykov/1375427': ('Ivan Bykov', 'acteur.', '0'), '/contact/Martin_Balsam/3627': ('Martin Balsam', 'acteur américain né le 4 novembre 1919 à New York. Il est décédé le 12 février 1996 à Rome (Italie).', '85 aiment'), '/contact/john_krasinski/84703': ('John Krasinski', 'acteur, réalisateur, producteur et scénariste américain né le 19 octobre 1979 à Newton.', '621 aiment'), '/contact/harrison_ford/994': ('Harrison Ford', 'acteur et producteur américain né le 12 juillet 1942 à Chicago.', '3.1K aiment'), '/contact/henry_daniell/486': ('Henry Daniell', 'acteur britannique né le 4 mars 1894 à Londres. Il est décédé le 30 octobre 1963 à Santa Monica (États-Unis).', '5 aiment'), '/contact/erwin_connelly/1355845': ('Erwin Connelly', 'acteur.', '0'), '/contact/Splendor_Films/422618': ('Splendor Films', 'Splendor Films est une société spécialisée dans la distribution.', '2 aiment'), '/contact/Melchior_Lengyel/501151': ('Melchior Lengyel', 'scénariste hongrois né le 11 janvier 1880 à Balmazújváros. Il est décédé le 22 octobre 1974 à Budapest.', '1 aime'), '/contact/kathryn_mc_guire/8734': ('Kathryn McGuire', 'actrice américaine née le 5 décembre 1903 à Peoria. Elle est décédée le 9 octobre 1978 à Los Angeles.', '2 aiment'), '/contact/tim_roth/17693': ('Tim Roth', 'acteur, artiste musical, réalisateur et producteur britannique né le 13 mai 1961 à Dulwich.', '1.4K aiment'), '/contact/Marc_Michel/3919': ('Marc Michel', 'acteur, auteur et scénariste suisse/français né le 10 février 1929 à Basse-Terre. Il est décédé le 2 novembre 2016 à Dreux.', '23 aiment'), '/contact/Anatoli_Solonitsyne/5072': ('Anatoli Solonitsyne', 'acteur soviétique né le 29 août 1934 à Bogorodsk. Il est décédé le 10 juin 1982 à Moscou.', '138 aiment'), '/contact/Liubomiras_Lauciavicius/1179265': ('Liubomiras Lauciavicius', 'acteur.', '2 aiment'), '/contact/james_stewart/970': ('James Stewart', 'acteur et artiste musical américain né le 19 mai 1908 à Indiana. Il est décédé le 1 juillet 1997 à Los Angeles.', '1.6K aiment'), '/contact/brad_dourif/1589': ('Brad Dourif', 'acteur américain né le 17 mars 1950 à Huntington.', '244 aiment'), '/contact/Irma_Raush/1984026': ('Irma Raush', 'acteur.', '0'), '/contact/akira_ishihama/98233': ('Akira Ishihama', 'acteur japonais né le 29 janvier 1935 à Tokyo. Il est décédé le 25 juillet 2022.', '10 aiment'), '/contact/tetsuro_tamba/505977': ('Tetsurō Tamba', 'acteur japonais né le 16 juillet 1922 à Tokyo. Il est décédé le 23 août 2006 à Tokyo.', '50 aiment'), '/contact/Action_Cinemas_Theatre_du_Temple/422327': ('Action Cinémas / Théâtre du Temple', 'Action Cinémas / Théâtre du Temple est une société spécialisée dans la distribution.', '3 aiment'), '/contact/sean_young/1591': ('Sean Young', 'actrice américaine née le 19 novembre 1959 à Louisville, Kentucky, USA.', '111 aiment'), '/contact/celeste_holm/9067': ('Celeste Holm', 'actrice et artiste musicale américaine née le 28 avril 1917 à New York. Elle ...

# %%
df_people = pd.DataFrame.from_dict(people_data, 
                                      orient='index', 
                                      columns=['person_name', 'description', 'likes']
                                          )

df_people.tail()
# Out:
#                                                person_name  \
# /contact/Nobuo_Nakamura/6480                Nobuo Nakamura
# /contact/Hiroyuki_Nishimoto/26790       Hiroyuki Nishimoto
# /contact/Charles_de_Lauzirika/543812  Charles de Lauzirika
# /contact/Ginzo_Sekiguchi/26788             Ginzô Sekiguchi
# /contact/Bino_Cicogna/51656                   Bino Cicogna
#
#                                                                             description  \
# /contact/Nobuo_Nakamura/6480          acteur japonais né le 13 septembre 1908 à Otar...
# /contact/Hiroyuki_Nishimoto/26790                                               acteur.
# /contact/Charles_de_Lauzirika/543812     acteur, réalisateur, producteur et scénariste.
# /contact/Ginzo_Sekiguchi/26788                                                  acteur.
# /contact/Bino_Cicogna/51656                                                 producteur.
#
#                                          likes
# /contact/Nobuo_Nakamura/6480          4 aiment
# /contact/Hiroyuki_Nishimoto/26790            0
# /contact/Charles_de_Lauzirika/543812  5 aiment
# /contact/Ginzo_Sekiguchi/26788               0
# /contact/Bino_Cicogna/51656                  0

# %% [markdown]
# ## Cleaning

# %% [markdown]
# Chack what we have now

# %%
# we have
print('df_ranking')
print(df_ranking.dtypes)
display(df_ranking.tail(1))

print('df_films_overall')
print(df_films_overall.dtypes)
display(df_films_overall.tail(1))

print('df_films_tech')
print(df_films_tech.dtypes)
display(df_films_tech.tail(1))

print('df_people')
print(df_people.dtypes)
display(df_people.tail(1))
# Out:
# df_ranking
# film_link    object
# ratings      object
# dtype: object
#                     film_link ratings
# 50.  /film/m_le_maudit/380190     8.1
# df_films_overall
# title                  object
# category               object
# likes                  object
# technical_info_link    object
# dtype: object
#                                                             title category  \
# /film/voyage_au_bout_de_l_enfer/376439  Voyage au bout de l'enfer     Film
#
#                                        likes  \
# /film/voyage_au_bout_de_l_enfer/376439  2.5K
#
#                                                                    technical_info_link
# /film/voyage_au_bout_de_l_enfer/376439  /film/voyage_au_bout_de_l_enfer/376439/details
# df_films_tech
# original_title         object
# also_known_as          object
# genres                 object
# release_year           object
# countries_of_origin    object
# duration               object
# release_date_orig      object
# release_date_france    object
# directors_link         object
# writers_link           object
# producers_link         object
# distributors_link      object
# actors_link            object
# budget                 object
# synopsis               object
# dtype: object
#                                                  original_title also_known_as  \
# /film/voyage_au_bout_de_l_enfer/376439/details  The Deer Hunter          None
#
#                                                          genres release_year  \
# /film/voyage_au_bout_de_l_enfer/376439/details  [Drame, Guerre]         1978
#
#                                                        countries_of_origin  \
# /film/voyage_au_bout_de_l_enfer/376439/details  [États-Unis,, Royaume-Uni]
#
#                                                   duration release_date_orig  \
# /film/voyage_au_bout_de_l_enfer/376439/details  3 h 03 min   8 décembre 1978
#
#                                                release_date_france  \
# /film/voyage_au_bout_de_l_enfer/376439/details         7 mars 1979
#
#                                                               directors_link  \
# /film/voyage_au_bout_de_l_enfer/376439/details  /contact/Michael_Cimino/5885
#
#                                                                      writers_link  \
# /film/voyage_au_bout_de_l_enfer/376439/details  [/contact/Deric_Washburn/1535256]
#
#                                                                                    producers_link  \
# /film/voyage_au_bout_de_l_enfer/376439/details  [/contact/Michael_Cimino/5885, /contact/Michae...
#
#                                                                distributors_link  \
# /film/voyage_au_bout_de_l_enfer/376439/details  [/contact/Carlotta_Films/422349]
#
#                                                                                       actors_link  \
# /film/voyage_au_bout_de_l_enfer/376439/details  [/contact/robert_de_niro/13, /contact/john_caz...
#
#                                                       budget  \
# /film/voyage_au_bout_de_l_enfer/376439/details  15 000 000 $
#
#                                                                                          synopsis
# /film/voyage_au_bout_de_l_enfer/376439/details  Une analyse en profondeur de la façon dont la ...
# df_people
# person_name    object
# description    object
# likes          object
# dtype: object
#                               person_name  description likes
# /contact/Bino_Cicogna/51656  Bino Cicogna  producteur.     0

# %% [markdown]
# In DataFrames, change saved *links* to *indexes* to connect tables on them

# %%
# deleting links and saving indexes


def extract_index(url):
    match = re.search(r'/(\d+)$', url) # Use regular expression to extract the index (digits) from the URL
    if match:
        return int(match.group(1))  # Convert to integer
    else:
        return None

def url_to_index_values(df):
    for col in df.columns:
        df[col] = df[col].apply(lambda cell: [extract_index(item) if isinstance(item, str) and re.search(r'/(\d+)$', item)
                                            else item for item in cell] if isinstance(cell, list) 
                                            else extract_index(cell) if isinstance(cell, str) and re.search(r'/(\d+)$', cell) 
                                            else cell)
    return df

def change_column_names(df):
    renamed_columns = {}
    for col in df.columns:
        if col.endswith('_link'):
            new_col_name = col[:-5] + '_index'
            renamed_columns[col] = new_col_name

    return df.rename(columns=renamed_columns)

def url_to_index(df):
    df = url_to_index_values(df)
    df = change_column_names(df)
    return df

    

df_ranking_cleaned = df_ranking.copy()
df_ranking_cleaned.reset_index(inplace=True)
df_ranking_cleaned = url_to_index(df_ranking_cleaned)

df_films_cleaned = pd.concat([df_films_overall, df_films_tech.rename(index=lambda x: x.replace('/details', ''))], axis=1, ignore_index=False).drop(columns=['technical_info_link'])
df_films_cleaned.reset_index(inplace=True)
df_films_cleaned = url_to_index(df_films_cleaned)

df_people_cleaned = df_people.copy()
df_people_cleaned.reset_index(inplace=True)
df_people_cleaned = url_to_index(df_people_cleaned)

      
display(df_ranking_cleaned.tail())
display(df_films_cleaned.tail())
display(df_people_cleaned.tail())
# Out:
#    index  film_index ratings
# 45   46.      448394     8.2
# 46   47.      415777     8.2
# 47   48.      372818     8.2
# 48   49.      407292     8.1
# 49   50.      380190     8.1
#      index                             title       category likes  \
# 45  494192                   Sherlock Junior  Moyen-métrage   580
# 46  390558                          Soy Cuba           Film   488
# 47  449273             Threat Level Midnight       Téléfilm   123
# 48  447958  Vol au-dessus d'un nid de coucou           Film  6.6K
# 49  376439         Voyage au bout de l'enfer           Film  2.5K
#
#                      original_title                     also_known_as  \
# 45                     Sherlock Jr.                              None
# 46                             None  [I Am Cuba,, Ya Kuba,, Я - Куба]
# 47                             None                              None
# 48  One Flew Over the Cuckoo's Nest                              None
# 49                  The Deer Hunter                              None
#
#                               genres release_year         countries_of_origin  \
# 45  [Muet, Comédie, Action, Romance]         1924                [États-Unis]
# 46                           [Drame]         1964   [Cuba,, Union Soviétique]
# 47                         [Comédie]         2011                [États-Unis]
# 48       [Drame, Comédie dramatique]         1975                [États-Unis]
# 49                   [Drame, Guerre]         1978  [États-Unis,, Royaume-Uni]
#
#       duration release_date_orig release_date_france  directors_index  \
# 45      45 min       11 mai 1924     28 octobre 1924             5696
# 46  2 h 21 min   26 octobre 1964     16 juillet 2003            10915
# 47      30 min              None     17 février 2011          1110101
# 48  2 h 13 min  21 novembre 1975         1 mars 1976              614
# 49  3 h 03 min   8 décembre 1978         7 mars 1979             5885
#
#         writers_index                producers_index distributors_index  \
# 45               None                [5696, 4864983]           [422618]
# 46  [123498, 3015618]                           None  [422298, 1126663]
# 47    [275178, 91341]                           None               None
# 48    [35309, 496203]              [525, 625, 11018]           [556452]
# 49          [1535256]  [5885, 5446312, 59968, 31541]           [422349]
#
#                                          actors_index        budget  \
# 45  [5696, 8734, 8831, 1355845, 12334, 5855205, 59...          None
# 46  [21087, 60003, 74774, 3226987, 74773, 932, 518...          None
# 47  [72401, 54016, 84703, 105750, 106764, 91341, 8...          None
# 48  [2, 11016, 11003, 7307, 1589, 32102, 7, 527, 1...    $4 400 000
# 49  [13, 9182, 1867, 759, 14, 22461, 59966, 20425,...  15 000 000 $
#
#                                              synopsis
# 45  Un projectionniste, qui rêve d'être détective,...
# 46  A travers quatre histoires, "Soy Cuba" décrit ...
# 47  Après 11 ans de préparation, Michael Scott nou...
# 48  Pour échapper à la prison, Randall P. McMurphy...
# 49  Une analyse en profondeur de la façon dont la ...
#       index           person_name  \
# 657    6480        Nobuo Nakamura
# 658   26790    Hiroyuki Nishimoto
# 659  543812  Charles de Lauzirika
# 660   26788       Ginzô Sekiguchi
# 661   51656          Bino Cicogna
#
#                                            description     likes
# 657  acteur japonais né le 13 septembre 1908 à Otar...  4 aiment
# 658                                            acteur.         0
# 659     acteur, réalisateur, producteur et scénariste.  5 aiment
# 660                                            acteur.         0
# 661                                        producteur.         0

# %% [markdown]
# For numbers, change their type to numerical

# %%
# fixing wrong format. ex: '46.' -> '46'

df_ranking_cleaned['index'] = df_ranking_cleaned['index'].str.rstrip('.').astype(int) 

# display(df_ranking_cleaned.tail())

# %%
def custom_converter(value): # Define a custom function to convert values to integers
    try:
        # Try to convert to integer directly
        return int(value)
    except ValueError:
        # If it's not a plain integer, check for 'K' and 'M'
        if value.endswith('K'):
            return int(float(value[:-1]) * 1000)
        elif value.endswith('M'):
            return int(float(value[:-1]) * 1000000)
        else:
            # Handle other cases as needed
            return None

df_films_cleaned['likes'] = df_films_cleaned['likes'].apply(custom_converter)
        
# display(df_films_cleaned.tail())

# %%
def clean_likes(value):
    try:
        return int(value)
    except ValueError:
        if 'aiment' in value:
            val = value.replace('aiment', '')
            try:
                return int(val)
            except ValueError:
                return custom_converter(val)
        else:
            return None


df_people_cleaned['likes'] = df_people_cleaned['likes'].apply(clean_likes)

# display(df_people_cleaned.tail())

# %% [markdown]
# If DataFrame will be used in SQL, creating new connections DataFrames for columns with lists, since SQL cannot read lists

# %%
# handling lists
# creating new tables with connections 
# bc sql can't read lists

# there are only lists in df_films_cleaned

def seperate_lists(df):
    exploded = {}
    for column in df.columns:
        if isinstance(df[column].iloc[0], list):  # Check if cell in the column contains a list
            exploded[column[:-6] if '_index' in column else column] = df[['index', column]].explode(column).dropna()
            df = df.drop(column, axis=1)
    df_exploded = {}
    for key, value in exploded.items():
        df_exploded[key] = pd.DataFrame(value)
    return(df, df_exploded)

df_films_cleaned_shortened, df_film_extra = seperate_lists(df_films_cleaned)


display(df_films_cleaned_shortened.tail())
for key, value in df_film_extra.items():
    display(df_film_extra[key].tail())
# Out:
#      index                             title       category  likes  \
# 45  494192                   Sherlock Junior  Moyen-métrage    580
# 46  390558                          Soy Cuba           Film    488
# 47  449273             Threat Level Midnight       Téléfilm    123
# 48  447958  Vol au-dessus d'un nid de coucou           Film   6600
# 49  376439         Voyage au bout de l'enfer           Film   2500
#
#                      original_title release_year    duration  \
# 45                     Sherlock Jr.         1924      45 min
# 46                             None         1964  2 h 21 min
# 47                             None         2011      30 min
# 48  One Flew Over the Cuckoo's Nest         1975  2 h 13 min
# 49                  The Deer Hunter         1978  3 h 03 min
#
#    release_date_orig release_date_france  directors_index        budget  \
# 45       11 mai 1924     28 octobre 1924             5696          None
# 46   26 octobre 1964     16 juillet 2003            10915          None
# 47              None     17 février 2011          1110101          None
# 48  21 novembre 1975         1 mars 1976              614    $4 400 000
# 49   8 décembre 1978         7 mars 1979             5885  15 000 000 $
#
#                                              synopsis
# 45  Un projectionniste, qui rêve d'être détective,...
# 46  A travers quatre histoires, "Soy Cuba" décrit ...
# 47  Après 11 ans de préparation, Michael Scott nou...
# 48  Pour échapper à la prison, Randall P. McMurphy...
# 49  Une analyse en profondeur de la façon dont la ...
#      index              also_known_as
# 43  404608  Requiem pour un Maϟϟacre,
# 43  404608               Иди и смотри
# 46  390558                 I Am Cuba,
# 46  390558                   Ya Kuba,
# 46  390558                   Я - Куба
#      index              genres
# 47  449273             Comédie
# 48  447958               Drame
# 48  447958  Comédie dramatique
# 49  376439               Drame
# 49  376439              Guerre
#      index countries_of_origin
# 46  390558    Union Soviétique
# 47  449273          États-Unis
# 48  447958          États-Unis
# 49  376439         États-Unis,
# 49  376439         Royaume-Uni
#      index writers_index
# 47  449273        275178
# 47  449273         91341
# 48  447958         35309
# 48  447958        496203
# 49  376439       1535256
#      index producers_index
# 48  447958           11018
# 49  376439            5885
# 49  376439         5446312
# 49  376439           59968
# 49  376439           31541
#      index distributors_index
# 45  494192             422618
# 46  390558             422298
# 46  390558            1126663
# 48  447958             556452
# 49  376439             422349
#      index actors_index
# 49  376439        22461
# 49  376439        59966
# 49  376439        20425
# 49  376439        22894
# 49  376439      1109124

# %%
# deleing commas at the end of variables
for key, value in df_film_extra.items():
    try:
        df_film_extra[key].iloc[:, 1] = df_film_extra[key].iloc[:, 1].str.replace(',', '')
    except:
        pass
    display(df_film_extra[key].tail())
# Out:
#      index             also_known_as
# 43  404608  Requiem pour un Maϟϟacre
# 43  404608              Иди и смотри
# 46  390558                 I Am Cuba
# 46  390558                   Ya Kuba
# 46  390558                  Я - Куба
#      index              genres
# 47  449273             Comédie
# 48  447958               Drame
# 48  447958  Comédie dramatique
# 49  376439               Drame
# 49  376439              Guerre
#      index countries_of_origin
# 46  390558    Union Soviétique
# 47  449273          États-Unis
# 48  447958          États-Unis
# 49  376439          États-Unis
# 49  376439         Royaume-Uni
#      index writers_index
# 47  449273        275178
# 47  449273         91341
# 48  447958         35309
# 48  447958        496203
# 49  376439       1535256
#      index producers_index
# 48  447958           11018
# 49  376439            5885
# 49  376439         5446312
# 49  376439           59968
# 49  376439           31541
#      index distributors_index
# 45  494192             422618
# 46  390558             422298
# 46  390558            1126663
# 48  447958             556452
# 49  376439             422349
#      index actors_index
# 49  376439        22461
# 49  376439        59966
# 49  376439        20425
# 49  376439        22894
# 49  376439      1109124

# %% [markdown]
# ## Result

# %% [markdown]
# Show seperate DataFrames with connections

# %%
print('df_films_cleaned_shortened')
display(df_films_cleaned_shortened.tail())

for key, value in df_film_extra.items():
    print('df_films_to_' + key)
    display(df_film_extra[key].tail())
# Out:
# df_films_cleaned_shortened
#      index                             title       category  likes  \
# 45  494192                   Sherlock Junior  Moyen-métrage    580
# 46  390558                          Soy Cuba           Film    488
# 47  449273             Threat Level Midnight       Téléfilm    123
# 48  447958  Vol au-dessus d'un nid de coucou           Film   6600
# 49  376439         Voyage au bout de l'enfer           Film   2500
#
#                      original_title release_year    duration  \
# 45                     Sherlock Jr.         1924      45 min
# 46                             None         1964  2 h 21 min
# 47                             None         2011      30 min
# 48  One Flew Over the Cuckoo's Nest         1975  2 h 13 min
# 49                  The Deer Hunter         1978  3 h 03 min
#
#    release_date_orig release_date_france  directors_index        budget  \
# 45       11 mai 1924     28 octobre 1924             5696          None
# 46   26 octobre 1964     16 juillet 2003            10915          None
# 47              None     17 février 2011          1110101          None
# 48  21 novembre 1975         1 mars 1976              614    $4 400 000
# 49   8 décembre 1978         7 mars 1979             5885  15 000 000 $
#
#                                              synopsis
# 45  Un projectionniste, qui rêve d'être détective,...
# 46  A travers quatre histoires, "Soy Cuba" décrit ...
# 47  Après 11 ans de préparation, Michael Scott nou...
# 48  Pour échapper à la prison, Randall P. McMurphy...
# 49  Une analyse en profondeur de la façon dont la ...
# df_films_to_also_known_as
#      index             also_known_as
# 43  404608  Requiem pour un Maϟϟacre
# 43  404608              Иди и смотри
# 46  390558                 I Am Cuba
# 46  390558                   Ya Kuba
# 46  390558                  Я - Куба
# df_films_to_genres
#      index              genres
# 47  449273             Comédie
# 48  447958               Drame
# 48  447958  Comédie dramatique
# 49  376439               Drame
# 49  376439              Guerre
# df_films_to_countries_of_origin
#      index countries_of_origin
# 46  390558    Union Soviétique
# 47  449273          États-Unis
# 48  447958          États-Unis
# 49  376439          États-Unis
# 49  376439         Royaume-Uni
# df_films_to_writers
#      index writers_index
# 47  449273        275178
# 47  449273         91341
# 48  447958         35309
# 48  447958        496203
# 49  376439       1535256
# df_films_to_producers
#      index producers_index
# 48  447958           11018
# 49  376439            5885
# 49  376439         5446312
# 49  376439           59968
# 49  376439           31541
# df_films_to_distributors
#      index distributors_index
# 45  494192             422618
# 46  390558             422298
# 46  390558            1126663
# 48  447958             556452
# 49  376439             422349
# df_films_to_actors
#      index actors_index
# 49  376439        22461
# 49  376439        59966
# 49  376439        20425
# 49  376439        22894
# 49  376439      1109124

# %% [markdown]
# Show DataFrames with all data

# %%
print('df_ranking_cleaned')
display(df_ranking_cleaned.tail())

print('df_films_cleaned')
display(df_films_cleaned.tail())

print('df_people_cleaned')
display(df_people_cleaned.tail())
# Out:
# df_ranking_cleaned
#     index  film_index ratings
# 45     46      448394     8.2
# 46     47      415777     8.2
# 47     48      372818     8.2
# 48     49      407292     8.1
# 49     50      380190     8.1
# df_films_cleaned
#      index                             title       category  likes  \
# 45  494192                   Sherlock Junior  Moyen-métrage    580
# 46  390558                          Soy Cuba           Film    488
# 47  449273             Threat Level Midnight       Téléfilm    123
# 48  447958  Vol au-dessus d'un nid de coucou           Film   6600
# 49  376439         Voyage au bout de l'enfer           Film   2500
#
#                      original_title                     also_known_as  \
# 45                     Sherlock Jr.                              None
# 46                             None  [I Am Cuba,, Ya Kuba,, Я - Куба]
# 47                             None                              None
# 48  One Flew Over the Cuckoo's Nest                              None
# 49                  The Deer Hunter                              None
#
#                               genres release_year         countries_of_origin  \
# 45  [Muet, Comédie, Action, Romance]         1924                [États-Unis]
# 46                           [Drame]         1964   [Cuba,, Union Soviétique]
# 47                         [Comédie]         2011                [États-Unis]
# 48       [Drame, Comédie dramatique]         1975                [États-Unis]
# 49                   [Drame, Guerre]         1978  [États-Unis,, Royaume-Uni]
#
#       duration release_date_orig release_date_france  directors_index  \
# 45      45 min       11 mai 1924     28 octobre 1924             5696
# 46  2 h 21 min   26 octobre 1964     16 juillet 2003            10915
# 47      30 min              None     17 février 2011          1110101
# 48  2 h 13 min  21 novembre 1975         1 mars 1976              614
# 49  3 h 03 min   8 décembre 1978         7 mars 1979             5885
#
#         writers_index                producers_index distributors_index  \
# 45               None                [5696, 4864983]           [422618]
# 46  [123498, 3015618]                           None  [422298, 1126663]
# 47    [275178, 91341]                           None               None
# 48    [35309, 496203]              [525, 625, 11018]           [556452]
# 49          [1535256]  [5885, 5446312, 59968, 31541]           [422349]
#
#                                          actors_index        budget  \
# 45  [5696, 8734, 8831, 1355845, 12334, 5855205, 59...          None
# 46  [21087, 60003, 74774, 3226987, 74773, 932, 518...          None
# 47  [72401, 54016, 84703, 105750, 106764, 91341, 8...          None
# 48  [2, 11016, 11003, 7307, 1589, 32102, 7, 527, 1...    $4 400 000
# 49  [13, 9182, 1867, 759, 14, 22461, 59966, 20425,...  15 000 000 $
#
#                                              synopsis
# 45  Un projectionniste, qui rêve d'être détective,...
# 46  A travers quatre histoires, "Soy Cuba" décrit ...
# 47  Après 11 ans de préparation, Michael Scott nou...
# 48  Pour échapper à la prison, Randall P. McMurphy...
# 49  Une analyse en profondeur de la façon dont la ...
# df_people_cleaned
#       index           person_name  \
# 657    6480        Nobuo Nakamura
# 658   26790    Hiroyuki Nishimoto
# 659  543812  Charles de Lauzirika
# 660   26788       Ginzô Sekiguchi
# 661   51656          Bino Cicogna
#
#                                            description  likes
# 657  acteur japonais né le 13 septembre 1908 à Otar...    4.0
# 658                                            acteur.    0.0
# 659     acteur, réalisateur, producteur et scénariste.    5.0
# 660                                            acteur.    0.0
# 661                                        producteur.    0.0
